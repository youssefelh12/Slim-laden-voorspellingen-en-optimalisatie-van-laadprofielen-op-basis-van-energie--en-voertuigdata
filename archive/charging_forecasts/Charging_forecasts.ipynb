# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn.metrics import r2_score
from pandas import read_csv
from datetime import datetime
from keras.layers import Dense, Dropout, SimpleRNN, LSTM
from keras.models import Sequential

# ----------------- load & index ---------------------------------
df = (pd.read_csv("./Charging_data_cleaned.csv",  # adjust path
                  parse_dates=["Date"])
        .set_index("Date")
        .sort_index())
'''
df = df.asfreq("h")                      # full hourly grid
df["raw"] = df["Chargers"]               # untouched copy

# ------------- build a year-month-hour key -----------------------
key = df.index.strftime("%Y-%m-%H")      # e.g. "2024-07-15"

# mean Chargers for each (year-month, hour-of-day) bucket
ymh_mean = df.groupby(key)["raw"].transform("mean")

# ------------------ gap filling ---------------------------------
df["Chargers"] = df["raw"].fillna(ymh_mean)
assert not df["Chargers"].isna().any(), "Still have gaps!"
'''
# ------------------ PLOT ----------------------------------------
plt.figure(figsize=(14, 4))
plt.plot(df.index, df["Chargers"], label="Charger consumption")
plt.title("Hourly charger consumption ", fontsize=16)
plt.xlabel("Time", fontsize=16)
plt.ylabel("kWh", fontsize=16)
plt.tight_layout()
plt.legend()
plt.show()

# ------------------ PLOT: since 2024-10 --------------------------
cutoff = "2024-10-01"            # YYYY-MM-DD string works with DatetimeIndex
recent = df.loc[cutoff:]         # same as df[df.index >= cutoff]

plt.figure(figsize=(14, 4))
plt.plot(recent.index, recent["Chargers"],
         label=f"Charger consumption (≥ {cutoff})")
plt.title("Hourly charger load (since Oct 2024)")
plt.xlabel("Time")
plt.ylabel("kWh")
plt.tight_layout()
plt.legend()
plt.show()

# %%
# ───────────────────────── IMPORTS ─────────────────────────
import math
from datetime import timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────────────────── CONFIG ─────────────────────────
TARGET_COL    = "Chargers"
DAYS_TRAIN    = 175                 # ← 100-day training window
HRS_PER_DAY   = 24
LOOK_BACK     = DAYS_TRAIN * HRS_PER_DAY        # 100 × 24 = 2 400 h
FORECAST_HR   = 24                              # 1-day forecast
SHOW_DAYS     = 2                               # how many past days to draw

# ─────────────────────── MAIN ───────────────────────
if __name__ == "__main__":

    # -------- df must already be in memory --------
    needed_rows = LOOK_BACK + FORECAST_HR         # 2 424 rows required
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows (got {len(df)})")
    
    # if you want to change the forecast date
    df_less = df.iloc[:]

    # keep the last 101 days (100 for training + 1 for truth/forecast)
    df_recent = df_less.iloc[-needed_rows:]

    # split 100-day history vs. day-101 truth
    df_hist = df_recent.iloc[:LOOK_BACK]          # rows 0 … 2 399
    df_real = df_recent.iloc[LOOK_BACK:]          # rows 2 400 … 2 423
    y_true  = df_real[TARGET_COL].values

    # ---------- mean-of-period forecast ----------
    hist_matrix = df_hist[TARGET_COL].values.reshape(DAYS_TRAIN, HRS_PER_DAY)
    preds = hist_matrix.mean(axis=0)              # length-24 vector

    idx_start = df_hist.index[-1] + timedelta(hours=1)
    pred_avg = pd.Series(
        preds,
        index=pd.date_range(idx_start, periods=FORECAST_HR, freq="H")
    )

    # ------------- evaluation metrics -------------
    mae  = mean_absolute_error(y_true, pred_avg.values)
    rmse = math.sqrt(mean_squared_error(y_true, pred_avg.values))
    r2   = r2_score(y_true, pred_avg.values)
    print(f"Mean-of-100-days →  MAE = {mae:6.2f}   RMSE = {rmse:6.2f}   R² = {r2:6.2f}")

    # ------------------- plot ---------------------
    past_to_show = df_hist.iloc[-SHOW_DAYS*HRS_PER_DAY:][TARGET_COL]  # last 3 × 24 rows
    actual = df_real[TARGET_COL]

    plt.figure(figsize=(12, 4))
    plt.plot(past_to_show.index, past_to_show.values,        label=f"Past {SHOW_DAYS} days")
    plt.plot(actual.index,     actual.values,  "-o",         label="Actual day-101")
    plt.plot(pred_avg.index,   pred_avg.values, "-o",        label="Mean-profile forecast")
    plt.title("Charger load – 100-day mean forecast")
    plt.xlabel("Hour")
    plt.ylabel("kWh")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Mean-of-100-days →  MAE =   8.91   RMSE =  20.07   R² =   0.58
# C:\Users\user\AppData\Local\Temp\ipykernel_10608\2429303867.py:43: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   index=pd.date_range(idx_start, periods=FORECAST_HR, freq="H")

# %%
# ───────────────────────── IMPORTS ─────────────────────────
import math
from datetime import timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────────────────── CONFIG ─────────────────────────
TARGET_COL  = "Chargers"
DAYS_BACK   = 175          # how far to look back
HRS_PER_DAY = 24
FORECAST_HR = 24               # 1-day forecast horizon
SHOW_DAYS   = 2              # how many past days to draw

# ─────────────────────── MAIN ───────────────────────
if __name__ == "__main__":

    # need 100 days of history + 1 day of truth
    needed_rows = DAYS_BACK * HRS_PER_DAY + FORECAST_HR
    '''
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows (got {len(df)})")
    '''

    # if you want to change the forecast date
    df_less = df.iloc[:]

    # keep the last 101 days (100 for training + 1 for truth/forecast)
    df_recent = df_less.iloc[-needed_rows:]

    # history vs. truth
    df_hist = df_recent.iloc[: DAYS_BACK * HRS_PER_DAY]    # 100 days
    df_real = df_recent.iloc[DAYS_BACK * HRS_PER_DAY :]    # forecast target (24 h)
    y_true  = df_real[TARGET_COL].values

    # -------- weekday-specific mean profiles --------
    n_weeks      = DAYS_BACK // 7          # 14 complete weeks inside 100 days
    hours_per_wd = n_weeks * HRS_PER_DAY   # 14 × 24 = 336 samples per weekday

    profiles = {}                          # weekday → 24-vector
    for wd in range(7):                    # 0 = Mon … 6 = Sun
        sel = df_hist[df_hist.index.weekday == wd][TARGET_COL].tail(hours_per_wd)
        if len(sel) < hours_per_wd:        # not enough full weeks? skip / fallback
            continue
        # reshape: (n_weeks, 24) then average down the weeks axis
        profiles[wd] = sel.values.reshape(n_weeks, HRS_PER_DAY).mean(axis=0)

    # fallback in case a profile is missing (rare)
    overall_profile = df_hist[TARGET_COL].values.reshape(-1, HRS_PER_DAY).mean(axis=0)

    # -------- choose the profile for the day we’re forecasting --------
    next_day_start = df_hist.index[-1] + timedelta(hours=1)       # first hr to predict
    next_wd        = next_day_start.weekday()
    preds          = profiles.get(next_wd, overall_profile)       # fallback to overall

    pred_avg = pd.Series(
        preds,
        index=pd.date_range(next_day_start, periods=FORECAST_HR, freq="h")
    )

    # -------- evaluation --------
    mae  = mean_absolute_error(y_true, pred_avg.values)
    rmse = math.sqrt(mean_squared_error(y_true, pred_avg.values))
    r2   = r2_score(y_true, pred_avg.values)
    print(f"Weekday-aware mean →  MAE = {mae:6.2f}   RMSE = {rmse:6.2f}   R² = {r2:6.2f}")

    # -------- plot (last 3 days + forecast) --------
    past_to_show = df_hist.iloc[-SHOW_DAYS * HRS_PER_DAY:][TARGET_COL]
    actual       = df_real[TARGET_COL]

    plt.figure(figsize=(12, 4))
    plt.plot(past_to_show.index, past_to_show.values, label=f"Past {SHOW_DAYS} days")
    plt.plot(actual.index,      actual.values,      "-o", label="Actual day-101")
    plt.plot(pred_avg.index,    pred_avg.values,    "-o", label="Weekday-mean forecast")
    plt.title("Charger load – weekday-specific mean (100-day window)")
    plt.xlabel("Hour")
    plt.ylabel("kWh")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Weekday-aware mean →  MAE =   5.94   RMSE =  12.14   R² =   0.85

# %%
# ───────────── imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from sklearn.metrics import (
    mean_absolute_error,
    r2_score,
    mean_absolute_percentage_error
)

# ───────────── config
TARGET_COL    = "Chargers"
DAYS_TRAIN    = 175          # history length (business days)
HRS_PER_DAY   = 24
LOOK_BACK     = DAYS_TRAIN * HRS_PER_DAY
FORECAST_DAYS = 30           # rolling back-test length (business days)
HOLIDAYS      = [pd.to_datetime("2025-04-21").date()]

# ------------------------------------------------------------------------------
# helper: build weekday → 24-hour mean profiles
# ------------------------------------------------------------------------------
def weekday_profiles(df_hist: pd.DataFrame) -> tuple[dict[int, np.ndarray], np.ndarray]:
    """
    Return a dictionary of weekday-specific hourly means and an overall fallback.
    df_hist must be *business days only*.
    """
    profiles = {}
    # overall weekday mean per hour (as fallback for missing weekdays)
    overall = (
        df_hist.groupby(df_hist["ds"].dt.hour)["y"]
        .mean()
        .reindex(range(24))
        .values
    )

    for wd in range(5):  # 0=Mon … 4=Fri
        sel = df_hist[df_hist["ds"].dt.dayofweek == wd]
        if sel.empty:
            continue
        profiles[wd] = (
            sel.groupby(sel["ds"].dt.hour)["y"]
            .mean()
            .reindex(range(24))
            .values
        )
    return profiles, overall


# ------------------------------------------------------------------------------
# MAIN
# ------------------------------------------------------------------------------
if __name__ == "__main__":

    # --- 1) bring data into Prophet-compatible layout: timestamp → 'ds', target → 'y'
    df_all = df.copy()
    if isinstance(df_all.index, pd.DatetimeIndex):
        df_all = df_all.reset_index()
        df_all.rename(columns={df_all.columns[0]: "ds"}, inplace=True)
    else:
        if df_all.columns[0] != "ds":
            df_all.rename(columns={df_all.columns[0]: "ds"}, inplace=True)
    df_all["ds"] = pd.to_datetime(df_all["ds"])

    # choose the y column
    data_cols = [c for c in df_all.columns if c != "ds"]
    if TARGET_COL in data_cols:
        source_col = TARGET_COL
    elif len(data_cols) == 1:
        source_col = data_cols[0]
        print(f"WARNING: TARGET_COL '{TARGET_COL}' not found. Using '{source_col}' as y.")
    else:
        raise KeyError(f"TARGET_COL '{TARGET_COL}' not found. Available: {data_cols}")
    df_all.rename(columns={source_col: "y"}, inplace=True)

    # --- 2) holiday zeroes + drop weekends
    df_all.loc[df_all["ds"].dt.date.isin(HOLIDAYS), "y"] = 0
    df_all = df_all[df_all["ds"].dt.dayofweek < 5].reset_index(drop=True)

    # --- 3) keep only the last LOOK_BACK hours + back-test span
    total_hours = LOOK_BACK + FORECAST_DAYS * HRS_PER_DAY
    df_recent = df_all.iloc[-total_hours:].reset_index(drop=True)

    unique_days    = np.sort(df_recent["ds"].dt.normalize().unique())
    forecast_days  = unique_days[-FORECAST_DAYS:]           # last 30 business days

    # storage for per-hour and per-day results
    records = []

    # ───────────── rolling back-test ─────────────
    for target_day in forecast_days:
        # split train / test
        train_df = df_recent[df_recent["ds"] < target_day]
        test_mask = (
            (df_recent["ds"] >= target_day)
            & (df_recent["ds"] < target_day + pd.Timedelta(days=1))
        )
        test_df = df_recent[test_mask]

        # --- build weekday profiles on *training* portion
        profiles, overall_profile = weekday_profiles(train_df)

        # --- produce the 24-hour forecast
        weekday_idx = pd.to_datetime(target_day).dayofweek
        y_pred = profiles.get(weekday_idx, overall_profile).copy()

        # night zeros + holiday zeros
        hours = test_df["ds"].dt.hour.values
        night_mask = (hours >= 18) | (hours < 6)
        y_pred[night_mask] = 0
        if pd.to_datetime(target_day).date() in HOLIDAYS:
            y_pred[:] = 0

        y_true = test_df["y"].values

        # metrics
        mae = mean_absolute_error(y_true, y_pred)
        mean_true = y_true.mean() if y_true.mean() != 0 else np.nan
        nmae = mae / mean_true if mean_true else np.nan
        r2_raw = r2_score(y_true, y_pred)
        r2 = max(r2_raw, 0)
        mape = mean_absolute_percentage_error(y_true, y_pred) * 100

        # store per-hour + per-day
        for ds_val, actual, pred in zip(test_df["ds"], y_true, y_pred):
            records.append(
                {
                    "ds": ds_val,
                    "actual": actual,
                    "forecast": pred,
                    "date": target_day,
                    "day_mae": mae,
                    "day_nmae": nmae,
                    "day_r2": r2,
                    "day_mape": mape,
                }
            )

        print(
            f"Day {pd.to_datetime(target_day).date()} → "
            f"MAE={mae:.2f}, NMAE={nmae:.3f}, "
            f"R²={r2:.2f} (raw {r2_raw:.2f}), MAPE={mape:.2f}%"
        )

    # --- 4) assemble results
    results = pd.DataFrame(records)

    # ------------------------------------------------------------------------------
    # PLOTS (identical to earlier version, plus box-plot)
    # ------------------------------------------------------------------------------

    # Plot 1 – Actual vs forecast (all hours)
    plt.figure(figsize=(14, 5))
    plt.plot(results["ds"], results["actual"], label="Actual")
    plt.plot(results["ds"], results["forecast"], label="Weekday-mean baseline", alpha=0.7)
    plt.title(f"Weekday-Mean Baseline – Last {FORECAST_DAYS} Business Days")
    plt.xlabel("Timestamp"); plt.ylabel("y"); plt.legend(); plt.tight_layout(); plt.show()

    # helper frames
    daily_err   = results[["date", "day_mae"]].drop_duplicates().sort_values("date")
    daily_nmae  = results[["date", "day_nmae"]].drop_duplicates().sort_values("date")
    daily_r2    = results[["date", "day_r2"]].drop_duplicates().sort_values("date")
    daily_mape  = results[["date", "day_mape"]].drop_duplicates().sort_values("date")

    # Daily MAE
    plt.figure(figsize=(10, 4))
    plt.plot(daily_err["date"], daily_err["day_mae"], marker="o")
    plt.title("Daily MAE"); plt.xlabel("Date"); plt.ylabel("MAE")
    plt.xticks(rotation=45); plt.tight_layout(); plt.show()

    # Daily NMAE
    plt.figure(figsize=(10, 4))
    plt.plot(daily_nmae["date"], daily_nmae["day_nmae"], marker="o")
    plt.title("Daily Normalised MAE"); plt.xlabel("Date"); plt.ylabel("NMAE")
    plt.xticks(rotation=45); plt.tight_layout(); plt.show()

    # Daily R²
    plt.figure(figsize=(10, 4))
    plt.plot(daily_r2["date"], daily_r2["day_r2"], marker="o")
    plt.title("Daily R² (non-negative)"); plt.xlabel("Date"); plt.ylabel("R²")
    plt.xticks(rotation=45); plt.tight_layout(); plt.show()

    # Averages by weekday (MAE / NMAE / MAPE / R²)
    weekday_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

    def bar_with_labels(series, title, ylab, fmt="%.2f"):
        fig, ax = plt.subplots(figsize=(10, 4))
        series = series.reindex(weekday_order)
        bars = ax.bar(series.index, series.values)
        ax.bar_label(
            bars,
            labels=[fmt % v for v in series.values],
            padding=0,
            fontsize=10,
            fontweight="bold",
        )
        ax.set_title(title); ax.set_xlabel("Weekday"); ax.set_ylabel(ylab)
        ax.yaxis.set_major_formatter(mtick.FormatStrFormatter(fmt))
        plt.xticks(rotation=45); plt.tight_layout(); plt.show()

    bar_with_labels(
        daily_err.assign(weekday=lambda d: pd.to_datetime(d["date"]).dt.day_name())
        .groupby("weekday")["day_mae"]
        .mean(),
        "Average MAE by Weekday",
        "MAE",
        "%.2f",
    )
    bar_with_labels(
        daily_nmae.assign(weekday=lambda d: pd.to_datetime(d["date"]).dt.day_name())
        .groupby("weekday")["day_nmae"]
        .mean(),
        "Average Normalised MAE by Weekday",
        "NMAE",
        "%.3f",
    )
    bar_with_labels(
        daily_mape.assign(weekday=lambda d: pd.to_datetime(d["date"]).dt.day_name())
        .groupby("weekday")["day_mape"]
        .mean(),
        "Average MAPE by Weekday",
        "MAPE (%)",
        "%.2f",
    )
    bar_with_labels(
        daily_r2.assign(weekday=lambda d: pd.to_datetime(d["date"]).dt.day_name())
        .groupby("weekday")["day_r2"]
        .mean(),
        "Average R² by Weekday",
        "R²",
        "%.2f",
    )

    # Box-plot (MAE & R² per day)
    plt.figure(figsize=(6, 4))
    plt.boxplot(
        [daily_err["day_mae"], daily_r2["day_r2"]],
        labels=["MAE", "R²"],
        showfliers=False,
    )
    plt.title("Distribution of Daily MAE and R² – Weekday-Mean Baseline")
    plt.tight_layout(); plt.show()

    # Overall averages
    print("\n───────── Baseline averages over the 30-day back-test ─────────")
    print(f"MAE : {daily_err['day_mae'].mean():.2f}")
    print(f"NMAE: {daily_nmae['day_nmae'].mean():.3f}")
    print(f"MAPE: {daily_mape['day_mape'].mean():.2f}%")
    print(f"R²  : {daily_r2['day_r2'].mean():.2f}")
# Out:
# Day 2025-03-28 → MAE=7.67, NMAE=0.446, R²=0.67 (raw 0.67), MAPE=198.01%
# Day 2025-03-31 → MAE=4.99, NMAE=0.239, R²=0.90 (raw 0.90), MAPE=76.97%
# Day 2025-04-01 → MAE=4.85, NMAE=0.322, R²=0.87 (raw 0.87), MAPE=917.03%
# Day 2025-04-02 → MAE=6.72, NMAE=0.995, R²=0.39 (raw 0.39), MAPE=932.63%
# Day 2025-04-03 → MAE=7.93, NMAE=0.332, R²=0.84 (raw 0.84), MAPE=332.92%
# Day 2025-04-04 → MAE=5.29, NMAE=1.011, R²=0.06 (raw 0.06), MAPE=893.23%
# Day 2025-04-07 → MAE=5.43, NMAE=0.341, R²=0.88 (raw 0.88), MAPE=151.66%
# Day 2025-04-08 → MAE=6.15, NMAE=0.336, R²=0.90 (raw 0.90), MAPE=963.73%
# Day 2025-04-09 → MAE=5.21, NMAE=0.419, R²=0.75 (raw 0.75), MAPE=304.41%
# Day 2025-04-10 → MAE=6.49, NMAE=0.388, R²=0.90 (raw 0.90), MAPE=743.03%
# Day 2025-04-11 → MAE=4.08, NMAE=0.335, R²=0.88 (raw 0.88), MAPE=164.75%
# Day 2025-04-14 → MAE=5.42, NMAE=0.430, R²=0.70 (raw 0.70), MAPE=224.43%
# Day 2025-04-15 → MAE=5.48, NMAE=0.357, R²=0.90 (raw 0.90), MAPE=283.38%
# Day 2025-04-16 → MAE=3.27, NMAE=0.319, R²=0.91 (raw 0.91), MAPE=1140.19%
# Day 2025-04-17 → MAE=7.47, NMAE=0.617, R²=0.65 (raw 0.65), MAPE=1025.75%
# Day 2025-04-18 → MAE=3.58, NMAE=0.524, R²=0.65 (raw 0.65), MAPE=355.11%
# Day 2025-04-21 → MAE=0.00, NMAE=nan, R²=1.00 (raw 1.00), MAPE=0.00%
# Day 2025-04-22 → MAE=13.56, NMAE=0.433, R²=0.73 (raw 0.73), MAPE=160.92%
# Day 2025-04-23 → MAE=5.45, NMAE=0.368, R²=0.87 (raw 0.87), MAPE=151.03%
# Day 2025-04-24 → MAE=2.99, NMAE=0.173, R²=0.96 (raw 0.96), MAPE=70.76%
# Day 2025-04-25 → MAE=8.85, NMAE=0.471, R²=0.70 (raw 0.70), MAPE=105.97%
# Day 2025-04-28 → MAE=12.28, NMAE=0.424, R²=0.73 (raw 0.73), MAPE=126.90%
# Day 2025-04-29 → MAE=4.43, NMAE=0.226, R²=0.94 (raw 0.94), MAPE=473.19%
# Day 2025-04-30 → MAE=3.16, NMAE=0.307, R²=0.91 (raw 0.91), MAPE=284.56%
# Day 2025-05-01 → MAE=17.71, NMAE=113.099, R²=0.00 (raw -165803933.97), MAPE=11422.86%
# Day 2025-05-02 → MAE=6.53, NMAE=1.625, R²=0.00 (raw -0.19), MAPE=1789.82%
# Day 2025-05-05 → MAE=4.60, NMAE=0.318, R²=0.85 (raw 0.85), MAPE=81.86%
# Day 2025-05-06 → MAE=8.12, NMAE=0.402, R²=0.86 (raw 0.86), MAPE=898.56%
# Day 2025-05-07 → MAE=6.38, NMAE=0.329, R²=0.82 (raw 0.82), MAPE=64.34%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 110
#     108 hours = test_df["ds"].dt.hour.values
#     109 night_mask = (hours >= 18) | (hours < 6)
# --> 110 y_pred[night_mask] = 0
#     111 if pd.to_datetime(target_day).date() in HOLIDAYS:
#     112     y_pred[:] = 0
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 24 but corresponding boolean dimension is 1

# %%
# ───────────────────────── IMPORTS ─────────────────────────
import math
from pathlib import Path
from datetime import timedelta

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import statsmodels.api as sm

# ───────────────────────── CONFIG ──────────────────────────
TARGET_COL   = "Chargers"
DAYS_TRAIN   = 175    # train on last 30 days
HRS_PER_DAY  = 24
LOOK_BACK    = DAYS_TRAIN * HRS_PER_DAY  # 720
N_FORECAST   = 24      # 1-day ahead
AR_ORDER     = 24      # AR(24)
SHOW_HOURS   = 2 * HRS_PER_DAY  # 72 h

if __name__ == "__main__":

    # ---------- load & sanity-check ----------
    # assume df is already in memory, indexed by pd.DatetimeIndex
    needed = LOOK_BACK + N_FORECAST
    if len(df) < needed:
        raise ValueError(f"Need ≥ {needed} rows (got {len(df)})")

    # last 30 days for training, next 24h for test
    df_recent = df.iloc[-needed:]
    df_train  = df_recent.iloc[:LOOK_BACK]
    df_test   = df_recent.iloc[LOOK_BACK:]
    y_train   = df_train[TARGET_COL].astype(float)
    y_test    = df_test[TARGET_COL]

    # ---------- fit AR(24) ----------
    model = sm.tsa.SARIMAX(y_train, order=(AR_ORDER, 0, 0),
                           enforce_stationarity=False,
                           enforce_invertibility=False)
    res = model.fit(disp=False)

    # ---------- 24-step forecast ----------
    preds = res.forecast(steps=N_FORECAST)

    # ── **CRUCIAL**: align the forecast’s index to your test set ──
    preds.index = df_test.index

    # ---------- evaluation ----------
    mae  = mean_absolute_error(y_test, preds)
    rmse = math.sqrt(mean_squared_error(y_test, preds))
    r2   = r2_score(y_test, preds)
    print(f"AR({AR_ORDER}) →  MAE = {mae:.2f}   RMSE = {rmse:.2f}   R² = {r2:.2f}")

    # ---------------- plot ---------------------
    hist_3d = df_train.iloc[-SHOW_HOURS:][TARGET_COL]

    plt.figure(figsize=(12, 4))
    plt.plot(hist_3d.index, hist_3d.values,      label="Past 72 h")
    plt.plot(df_test.index,   y_test.values,     "-o", label="Actual next day")
    plt.plot(preds.index,     preds.values,      "-o", label="Sarimax forecast")

    plt.title("Charger load – Sarimax forecast")
    plt.xlabel("Hour")
    plt.ylabel("kWh")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# AR(24) →  MAE = 6.30   RMSE = 10.54   R² = 0.89
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
"""
LSTM(1×32) baseline – train on the last 30 days, forecast the last 24 h
────────────────────────────────────────────────────────────────────────
• no extra calendar / holiday / EV features
• scales the 30-day window to [0,1], builds many (24→1) training pairs
• walk-forward generates a 24-step forecast
• prints MAE / RMSE / R2 vs. the real last-day values
• shows past-vs-forecast plot
"""

# ───────────────────────── IMPORTS ─────────────────────────
import math
from pathlib import Path
from datetime import timedelta
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# ───────────────────────── CONFIG ──────────────────────────
TARGET_COL   = "Chargers"

DAYS_TRAIN   = 175    # train horizon
HRS_PER_DAY  = 24
LOOK_BACK    = DAYS_TRAIN * HRS_PER_DAY     # 30 × 24 = 720
N_FORECAST   = 24        # forecast 1 day ahead

SEQ_LEN      = 24       # how many lags the LSTM sees  (1 per hour)
LSTM_UNITS   = 64      # neurons in the LSTM layer
EPOCHS       = 75
BATCH_SIZE   = 16
SEED         = 42

# reproducibility
np.random.seed(SEED); random.seed(SEED); tf.random.set_seed(SEED)

# ─────────────────────── MAIN ───────────────────────
if __name__ == "__main__":

    # ---------- load & sanity-check ----------
    # (assumes you already have df with a DateTimeIndex & “Chargers” col)
    needed_rows = LOOK_BACK + N_FORECAST
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows (got {len(df)})")
    
    df_less = df.iloc[:]

    # keep only the *last* 31 days (30 for training, 1 for test)
    df_recent = df_less.iloc[-needed_rows:]

    


    df_train = df_recent.iloc[:LOOK_BACK]          # 30 days
    df_test  = df_recent.iloc[LOOK_BACK:]          # final 24 h
    y_train  = df_train[TARGET_COL].values.reshape(-1, 1)
    y_test   = df_test[TARGET_COL].values.reshape(-1, 1)

    # ---------- scaling ----------
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train).flatten()

    # ---------- build (X,y) pairs ----------
    X, y = [], []
    for i in range(len(y_train_scaled) - SEQ_LEN):
        X.append(y_train_scaled[i : i + SEQ_LEN])
        y.append(y_train_scaled[i + SEQ_LEN])
    X = np.array(X).reshape(-1, SEQ_LEN, 1)   # (samples, timesteps, features)
    y = np.array(y)

    # ---------- define & fit LSTM ----------
    model = Sequential([
        LSTM(LSTM_UNITS, input_shape=(SEQ_LEN, 1)),
        Dense(1, activation="linear")
    ])
    model.compile(loss="mse", optimizer="adam")
    model.fit(X, y, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=0)

    # ---------- 24-step walk-forward forecast ----------
    last_seq = y_train_scaled[-SEQ_LEN:].tolist()    # start-state (scaled)
    preds_scaled = []
    for _ in range(N_FORECAST):
        x_input = np.array(last_seq[-SEQ_LEN:]).reshape(1, SEQ_LEN, 1)
        next_val = model.predict(x_input, verbose=0)[0, 0]
        preds_scaled.append(next_val)
        last_seq.append(next_val)

    preds = scaler.inverse_transform(np.array(preds_scaled).reshape(-1, 1)).flatten()

    # ---------- evaluation ----------
    mae  = mean_absolute_error(y_test, preds)
    rmse = math.sqrt(mean_squared_error(y_test, preds))
    r2   = r2_score(y_test, preds)
    print(f"LSTM(1×{LSTM_UNITS}) →  MAE = {mae:6.2f}   RMSE = {rmse:6.2f}   R2 = {r2:6.2f}")

    # ---------------- plot (3-day window) ----------------
    hrs_history = 2 * 24                 # 72 h
    hist_3d = df_recent.iloc[-(hrs_history + N_FORECAST):-N_FORECAST]   # last 3 days

    plt.figure(figsize=(12, 4))
    plt.plot(hist_3d.index, hist_3d[TARGET_COL], label="Past 72 h")
    plt.plot(df_test.index, y_test.flatten(), "-o", label="Actual day-31")
    plt.plot(df_test.index, preds, "-o", label="LSTM forecast")
    plt.title("Charger load – LSTM forecast")
    plt.xlabel("Hour"); plt.ylabel("kWh")
    plt.legend(); plt.tight_layout(); plt.show()
# Out:
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[162], line 82
#      77 model = Sequential([
#      78     LSTM(LSTM_UNITS, input_shape=(SEQ_LEN, 1)),
#      79     Dense(1, activation="linear")
#      80 ])
#      81 model.compile(loss="mse", optimizer="adam")
# ---> 82 model.fit(X, y, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=0)
#      84 # ---------- 24-step walk-forward forecast ----------
#      85 last_seq = y_train_scaled[-SEQ_LEN:].tolist()    # start-state (scaled)
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# ───────────── imports
import math, numpy as np, pandas as pd, matplotlib.pyplot as plt, lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────── config
TARGET_COL, DAYS_TRAIN, HRS_PER_DAY = "Chargers", 175, 24
LOOK_BACK, N_FORECAST = DAYS_TRAIN * HRS_PER_DAY, 24

LGB_PARAMS = dict(
    n_estimators      = 3000,
    learning_rate     = 0.05,
    num_leaves        = 128,
    subsample         = 0.8,
    colsample_bytree  = 0.8,
    objective         = "regression_l2",
    min_child_samples = 20,
    lambda_l1         = 0.1,
    lambda_l2         = 0.2,
    random_state      = 42,
    verbosity         = -1
)

# ───────────── helpers
def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    feats = pd.DataFrame(index=idx)
    feats["hour"], feats["dow"], feats["month"] = idx.hour, idx.dayofweek, idx.month
    feats["hour_sin"] = np.sin(2*np.pi*feats.hour/23);  feats["hour_cos"] = np.cos(2*np.pi*feats.hour/23)
    feats["dow_sin"]  = np.sin(2*np.pi*feats.dow/6);   feats["dow_cos"]  = np.cos(2*np.pi*feats.dow/6)
    return feats

# ───────────── main
if __name__ == "__main__":
    needed_rows = LOOK_BACK + N_FORECAST + 24          # +24 for lag feature
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows, got {len(df)}")

    df_recent = df.iloc[-needed_rows:]
    df_recent["lag_24"] = df_recent[TARGET_COL].shift(24)

    df_train_raw = df_recent.iloc[:-N_FORECAST]
    dow_mean = df_train_raw.groupby(df_train_raw.index.dayofweek)[TARGET_COL].mean()
    df_recent["weekday_avg"] = df_recent.index.dayofweek.map(dow_mean)

    df_recent = df_recent.dropna(subset=["lag_24", "weekday_avg"])
    split_pt  = len(df_recent) - N_FORECAST
    df_train, df_test = df_recent.iloc[:split_pt], df_recent.iloc[split_pt:]

    def build(frame):
        return make_calendar_features(frame.index).join(frame[["lag_24","weekday_avg"]])

    X_train, y_train = build(df_train), df_train[TARGET_COL]
    X_test,  y_test  = build(df_test),  df_test[TARGET_COL]

    # ────────── LightGBM fit (no “verbose=” argument)
    gbm = lgb.LGBMRegressor(**LGB_PARAMS)
    gbm.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric="l2",
        
        callbacks=[lgb.log_evaluation(period=0)]   # silences native logs
    )

    preds = gbm.predict(X_test)

    mae  = mean_absolute_error(y_test, preds)
    rmse = math.sqrt(mean_squared_error(y_test, preds))
    r2   = r2_score(y_test, preds)
    print(f"LightGBM (+lag24 +weekday_avg) → MAE {mae:6.2f}  RMSE {rmse:6.2f}  R² {r2:6.2f}")

    # ────────── plot
    hrs_hist = 48
    hist = df_recent.iloc[-(hrs_hist+N_FORECAST):-N_FORECAST]
    plt.figure(figsize=(12,4))
    plt.plot(hist.index, hist[TARGET_COL], label="Past 72 h")
    plt.plot(y_test.index, y_test, "-o", label="Actual")
    plt.plot(y_test.index, preds, "-o", label="Forecast")
    plt.title("Charger load – LightGBM ")
    plt.xlabel("Hour");  plt.ylabel("kWh");  plt.legend();  plt.tight_layout();  plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20128\2212643125.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent["lag_24"] = df_recent[TARGET_COL].shift(24)
# C:\Users\user\AppData\Local\Temp\ipykernel_20128\2212643125.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent["weekday_avg"] = df_recent.index.dayofweek.map(dow_mean)
# LightGBM (+lag24 +weekday_avg) → MAE   6.39  RMSE  10.88  R²   0.66

# %%
# ───────────── imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────── config
TARGET_COL, DAYS_TRAIN, HRS_PER_DAY = "Chargers", 175 , 24
LOOK_BACK, N_FORECAST = DAYS_TRAIN * HRS_PER_DAY, 24

LGB_PARAMS = dict(
    n_estimators      = 3000,
    learning_rate     = 0.05,
    num_leaves        = 128,
    subsample         = 0.8,
    colsample_bytree  = 0.8,
    objective         = "regression_l2",
    min_child_samples = 20,
    lambda_l1         = 0.1,
    lambda_l2         = 0.2,
    random_state      = 42,
    verbosity         = -1
)

if __name__ == "__main__":

    # ---- need enough data for 24-h lag + train + test
    needed_rows = LOOK_BACK + N_FORECAST + HRS_PER_DAY
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows, got {len(df)}")
    
    df_less = df.iloc[:]

    # ---- take the last block, then build only the 24-h lag
    df_recent = df_less.iloc[-needed_rows:].copy()
    df_recent["lag_24"] = df_recent[TARGET_COL].shift(HRS_PER_DAY)
    df_recent["day_of_week"] = df_recent.index.dayofweek

    

    # ---- calculate weekday average ----
    weekday_avg = df_recent.groupby('day_of_week')[TARGET_COL].transform('mean')
    df_recent["weekday_avg"] = weekday_avg

    # drop the first 24h (where lag is NaN)
    df_recent = df_recent.dropna(subset=["lag_24"])

    # split into train vs. test
    split_pt     = len(df_recent) - N_FORECAST
    df_train     = df_recent.iloc[:split_pt]
    df_test      = df_recent.iloc[split_pt:]
    X_train, y_train = df_train[["lag_24"]], df_train[TARGET_COL]
    X_test,  y_test  = df_test[ ["lag_24"]], df_test[ TARGET_COL]

    # ---- fit LightGBM on the single lag feature ----
    gbm = lgb.LGBMRegressor(**LGB_PARAMS)
    gbm.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric="l2",
        callbacks=[lgb.log_evaluation(period=0)]
    )

    # ---- predict and evaluate ----
    preds = gbm.predict(X_test)
    mae  = mean_absolute_error(y_test, preds)
    rmse = math.sqrt(mean_squared_error(y_test, preds))
    r2   = r2_score(y_test, preds)
    print(f"LightGBM (lag-24 only) → MAE {mae:6.2f}  RMSE {rmse:6.2f}  R² {r2:6.2f}")

    # ---- plot last 72h history + 24h forecast ----
    hrs_hist = 2 * HRS_PER_DAY
    hist     = df_recent.iloc[-(hrs_hist + N_FORECAST):-N_FORECAST][TARGET_COL]

    plt.figure(figsize=(12,4))
    plt.plot(hist.index,     hist,    label="Past 72 h")
    plt.plot(y_test.index,   y_test,  "-o", label="Actual next day")
    plt.plot(y_test.index,   preds,   "-o", label="LightGBM Forecast")
    plt.title("Charger load – LightGBM forecast")
    plt.xlabel("Hour"); plt.ylabel("kWh")
    plt.legend(); plt.tight_layout(); plt.show()
# Out:
# LightGBM (lag-24 only) → MAE   4.45  RMSE   6.33  R²   0.88

# %%
# ───────────── imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────── config
TARGET_COL, DAYS_TRAIN, HRS_PER_DAY = "Chargers", 175, 24
LOOK_BACK, N_FORECAST = DAYS_TRAIN * HRS_PER_DAY, 24

CATBOOST_PARAMS = dict(
    iterations        = 3000,
    learning_rate     = 0.05,
    depth             = 6,
    subsample         = 0.8,
    colsample_bylevel = 0.8,
    loss_function     = "MAE",
    l2_leaf_reg       = 3,
    random_seed       = 42,
    verbose           = False
)

if __name__ == "__main__":

    # ---- check required rows ----
    needed_rows = LOOK_BACK + N_FORECAST + HRS_PER_DAY
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows, got {len(df)}")

    df_less = df.iloc[:]

    # ---- last block & lag ----
    df_recent = df_less.iloc[-needed_rows:].copy()
    df_recent["lag_24"] = df_recent[TARGET_COL].shift(HRS_PER_DAY)
    df_recent["day_of_week"] = df_recent.index.dayofweek

    

    # ---- calculate weekday average ----
    weekday_avg = df_recent.groupby('day_of_week')[TARGET_COL].transform('mean')
    df_recent["weekday_avg"] = weekday_avg

    # ---- remove weekends ----
    df_recent = df_recent[df_recent["day_of_week"] < 5].reset_index(drop=True)
    

    df_recent = df_recent.dropna(subset=["lag_24"])

    # ---- split train/test ----
    split_pt = len(df_recent) - N_FORECAST
    df_train = df_recent.iloc[:split_pt]
    df_test = df_recent.iloc[split_pt:]
    X_train, y_train = df_train[["lag_24", "day_of_week"]], df_train[TARGET_COL]
    X_test, y_test = df_test[["lag_24", "day_of_week"]], df_test[TARGET_COL]

    # ---- fit CatBoost ----
    cbr = CatBoostRegressor(**CATBOOST_PARAMS)
    cbr.fit(X_train, y_train, eval_set=(X_test, y_test), use_best_model=True)

    # ---- predict and evaluate ----
    preds = cbr.predict(X_test)
    mae = mean_absolute_error(y_test, preds)
    rmse = math.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds)
    print(f"CatBoost (lag-24 + weekday) → MAE {mae:6.2f}  RMSE {rmse:6.2f}  R² {r2:6.2f}")

    # ---- plot ----
    hrs_hist = 2 * HRS_PER_DAY
    hist = df_recent.iloc[-(hrs_hist + N_FORECAST):-N_FORECAST][TARGET_COL]

    plt.figure(figsize=(12, 4))
    plt.plot(hist.index, hist, label="Past 72 h")
    plt.plot(y_test.index, y_test, "-o", label="Actual next day")
    plt.plot(y_test.index, preds, "-o", label="Catboost Forecast")
    plt.title("Charger load – CatBoost forecast")
    plt.xlabel("Hour")
    plt.ylabel("kWh")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# CatBoost (lag-24 + weekday) → MAE   7.75  RMSE  13.19  R²   0.83

# %%
# ───────────── imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────── config
TARGET_COL, DAYS_TRAIN, HRS_PER_DAY = "Chargers", 175, 24
LOOK_BACK, N_FORECAST = DAYS_TRAIN * HRS_PER_DAY, 24

XGB_PARAMS = dict(
    n_estimators      = 3000,
    learning_rate     = 0.05,
    max_depth         = 6,
    subsample         = 0.8,
    colsample_bytree  = 0.8,
    objective         = "reg:absoluteerror",
    reg_lambda        = 3,
    random_state      = 42,
    verbosity         = 0
)

if __name__ == "__main__":

    # ---- check required rows ----
    needed_rows = LOOK_BACK + N_FORECAST + HRS_PER_DAY
    if len(df) < needed_rows:
        raise ValueError(f"Need ≥ {needed_rows} rows, got {len(df)}")

    df_less = df.iloc[:]

    # ---- last block & lag ----
    df_recent = df_less.iloc[-needed_rows:].copy()
    df_recent["lag_24"] = df_recent[TARGET_COL].shift(HRS_PER_DAY)
    df_recent["day_of_week"] = df_recent.index.dayofweek

    # ---- calculate weekday average ----
    weekday_avg = df_recent.groupby('day_of_week')[TARGET_COL].transform('mean')
    df_recent["weekday_avg"] = weekday_avg

    # ---- remove weekends ----
    df_recent = df_recent[df_recent["day_of_week"] < 5].reset_index(drop=True)

    df_recent = df_recent.dropna(subset=["lag_24"])

    # ---- split train/test ----
    split_pt = len(df_recent) - N_FORECAST
    df_train = df_recent.iloc[:split_pt]
    df_test = df_recent.iloc[split_pt:]
    X_train, y_train = df_train[["lag_24", "day_of_week", "weekday_avg"]], df_train[TARGET_COL]
    X_test, y_test = df_test[["lag_24", "day_of_week", "weekday_avg"]], df_test[TARGET_COL]

    # ---- fit XGBoost ----
    xgbr = xgb.XGBRegressor(**XGB_PARAMS)
    xgbr.fit(X_train, y_train, eval_set=[(X_test, y_test)])

    # ---- predict and evaluate ----
    preds = xgbr.predict(X_test)
    mae = mean_absolute_error(y_test, preds)
    rmse = math.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds)
    print(f"XGBoost (lag-24 + weekday + weekday_avg) → MAE {mae:6.2f}  RMSE {rmse:6.2f}  R² {r2:6.2f}")

    # ---- plot ----
    hrs_hist = 2 * HRS_PER_DAY
    hist = df_recent.iloc[-(hrs_hist + N_FORECAST):-N_FORECAST][TARGET_COL]

    plt.figure(figsize=(12, 4))
    plt.plot(hist.index, hist, label="Past 72 h")
    plt.plot(y_test.index, y_test, "-o", label="Actual next day")
    plt.plot(y_test.index, preds, "-o", label="Forecast")
    plt.title("Charger load – XGBoost forecast")
    plt.xlabel("Hour")
    plt.ylabel("kWh")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# [0]	validation_0-mae:9.63907
# [1]	validation_0-mae:9.14869
# [2]	validation_0-mae:9.14870
# [3]	validation_0-mae:9.14871
# [4]	validation_0-mae:8.58589
# [5]	validation_0-mae:8.03835
# [6]	validation_0-mae:7.55270
# [7]	validation_0-mae:7.14342
# [8]	validation_0-mae:7.14343
# [9]	validation_0-mae:7.14345
# [10]	validation_0-mae:6.67594
# [11]	validation_0-mae:6.35039
# [12]	validation_0-mae:5.99841
# [13]	validation_0-mae:5.58989
# [14]	validation_0-mae:5.58989
# [15]	validation_0-mae:5.32745
# [16]	validation_0-mae:5.32746
# [17]	validation_0-mae:4.98058
# [18]	validation_0-mae:4.71042
# [19]	validation_0-mae:4.44937
# [20]	validation_0-mae:4.23213
# [21]	validation_0-mae:4.00730
# [22]	validation_0-mae:3.79261
# [23]	validation_0-mae:3.68776
# [24]	validation_0-mae:3.68777
# [25]	validation_0-mae:3.58058
# [26]	validation_0-mae:3.44783
# [27]	validation_0-mae:3.44784
# [28]	validation_0-mae:3.32710
# [29]	validation_0-mae:3.22261
# [30]	validation_0-mae:3.16858
# [31]	validation_0-mae:3.16858
# [32]	validation_0-mae:3.16858
# [33]	validation_0-mae:3.13620
# [34]	validation_0-mae:3.11045
# [35]	validation_0-mae:3.02845
# [36]	validation_0-mae:2.95003
# [37]	validation_0-mae:2.95003
# [38]	validation_0-mae:2.87350
# [39]	validation_0-mae:2.88035
# [40]	validation_0-mae:2.85444
# [41]	validation_0-mae:2.85444
# [42]	validation_0-mae:2.83352
# [43]	validation_0-mae:2.82898
# [44]	validation_0-mae:2.80896
# [45]	validation_0-mae:2.78209
# [46]	validation_0-mae:2.76942
# [47]	validation_0-mae:2.76082
# [48]	validation_0-mae:2.76082
# [49]	validation_0-mae:2.76082
# [50]	validation_0-mae:2.73248
# [51]	validation_0-mae:2.70678
# [52]	validation_0-mae:2.70678
# [53]	validation_0-mae:2.67370
# [54]	validation_0-mae:2.66768
# [55]	validation_0-mae:2.65454
# [56]	validation_0-mae:2.66494
# [57]	validation_0-mae:2.66494
# [58]	validation_0-mae:2.69391
# [59]	validation_0-mae:2.69391
# [60]	validation_0-mae:2.71818
# [61]	validation_0-mae:2.72779
# [62]	validation_0-mae:2.67230
# [63]	validation_0-mae:2.69334
# [64]	validation_0-mae:2.74909
# [65]	validation_0-mae:2.76655
# [66]	validation_0-mae:2.78579
# [67]	validation_0-mae:2.77047
# [68]	validation_0-mae:2.77047
# [69]	validation_0-mae:2.79182
# [70]	validation_0-mae:2.80848
# [71]	validation_0-mae:2.80848
# [72]	validation_0-mae:2.83040
# [73]	validation_0-mae:2.83040
# [74]	validation_0-mae:2.85558
# [75]	validation_0-mae:2.86168
# [76]	validation_0-mae:2.86168
# [77]	validation_0-mae:2.86168
# [78]	validation_0-mae:2.87064
# [79]	validation_0-mae:2.87064
# [80]	validation_0-mae:2.87064
# [81]	validation_0-mae:2.91539
# [82]	validation_0-mae:2.93267
# [83]	validation_0-mae:2.96978
# [84]	validation_0-mae:2.96978
# [85]	validation_0-mae:2.99428
# [86]	validation_0-mae:2.99428
# [87]	validation_0-mae:2.97094
# [88]	validation_0-mae:2.99308
# [89]	validation_0-mae:3.00685
# [90]	validation_0-mae:3.00685
# [91]	validation_0-mae:3.00963
# [92]	validation_0-mae:3.00900
# [93]	validation_0-mae:3.00553
# [94]	validation_0-mae:3.02328
# [95]	validation_0-mae:3.03939
# [96]	validation_0-mae:3.06234
# [97]	validation_0-mae:3.08365
# [98]	validation_0-mae:3.09066
# [99]	validation_0-mae:3.09066
# [100]	validation_0-mae:3.09066
# [101]	validation_0-mae:3.10842
# [102]	validation_0-mae:3.15780
# [103]	validation_0-mae:3.13753
# [104]	validation_0-mae:3.13753
# [105]	validation_0-mae:3.13753
# [106]	validation_0-mae:3.14814
# [107]	validation_0-mae:3.14814
# [108]	validation_0-mae:3.14814
# [109]	validation_0-mae:3.18033
# [110]	validation_0-mae:3.19174
# [111]	validation_0-mae:3.16156
# [112]	validation_0-mae:3.16416
# [113]	validation_0-mae:3.16416
# [114]	validation_0-mae:3.16695
# [115]	validation_0-mae:3.18055
# [116]	validation_0-mae:3.15132
# [117]	validation_0-mae:3.14035
# [118]	validation_0-mae:3.13716
# [119]	validation_0-mae:3.16040
# [120]	validation_0-mae:3.16040
# [121]	validation_0-mae:3.16040
# [122]	validation_0-mae:3.19677
# [123]	validation_0-mae:3.19677
# [124]	validation_0-mae:3.19540
# [125]	validation_0-mae:3.19540
# [126]	validation_0-mae:3.21254
# [127]	validation_0-mae:3.20569
# [128]	validation_0-mae:3.20867
# [129]	validation_0-mae:3.23108
# [130]	validation_0-mae:3.23108
# [131]	validation_0-mae:3.23108
# [132]	validation_0-mae:3.23108
# [133]	validation_0-mae:3.23108
# [134]	validation_0-mae:3.23108
# [135]	validation_0-mae:3.23108
# [136]	validation_0-mae:3.23108
# [137]	validation_0-mae:3.22470
# [138]	validation_0-mae:3.22470
# [139]	validation_0-mae:3.22213
# [140]	validation_0-mae:3.22118
# [141]	validation_0-mae:3.22118
# [142]	validation_0-mae:3.19481
# [143]	validation_0-mae:3.19481
# [144]	validation_0-mae:3.19518
# [145]	validation_0-mae:3.19518
# [146]	validation_0-mae:3.18812
# [147]	validation_0-mae:3.18812
# [148]	validation_0-mae:3.18404
# [149]	validation_0-mae:3.18404
# [150]	validation_0-mae:3.19666
# [151]	validation_0-mae:3.15409
# [152]	validation_0-mae:3.15257
# [153]	validation_0-mae:3.15399
# [154]	validation_0-mae:3.13172
# [155]	validation_0-mae:3.13041
# [156]	validation_0-mae:3.12721
# [157]	validation_0-mae:3.09161
# [158]	validation_0-mae:3.09029
# [159]	validation_0-mae:3.09029
# [160]	validation_0-mae:3.09029
# [161]	validation_0-mae:3.08066
# [162]	validation_0-mae:3.08066
# [163]	validation_0-mae:3.08066
# [164]	validation_0-mae:3.08053
# [165]	validation_0-mae:3.10583
# [166]	validation_0-mae:3.10583
# [167]	validation_0-mae:3.10943
# [168]	validation_0-mae:3.09902
# [169]	validation_0-mae:3.09332
# [170]	validation_0-mae:3.09732
# [171]	validation_0-mae:3.12659
# [172]	validation_0-mae:3.11845
# [173]	validation_0-mae:3.14211
# [174]	validation_0-mae:3.14953
# [175]	validation_0-mae:3.14967
# [176]	validation_0-mae:3.14793
# [177]	validation_0-mae:3.14308
# [178]	validation_0-mae:3.14308
# [179]	validation_0-mae:3.14154
# [180]	validation_0-mae:3.14154
# [181]	validation_0-mae:3.14154
# [182]	validation_0-mae:3.14154
# [183]	validation_0-mae:3.14176
# [184]	validation_0-mae:3.13583
# [185]	validation_0-mae:3.13480
# [186]	validation_0-mae:3.13388
# [187]	validation_0-mae:3.13559
# [188]	validation_0-mae:3.13443
# [189]	validation_0-mae:3.13443
# [190]	validation_0-mae:3.13240
# [191]	validation_0-mae:3.13289
# [192]	validation_0-mae:3.12650
# [193]	validation_0-mae:3.11396
# [194]	validation_0-mae:3.11362
# [195]	validation_0-mae:3.11230
# [196]	validation_0-mae:3.11230
# [197]	validation_0-mae:3.11295
# [198]	validation_0-mae:3.13704
# [199]	validation_0-mae:3.13701
# [200]	validation_0-mae:3.14666
# [201]	validation_0-mae:3.14666
# [202]	validation_0-mae:3.14665
# [203]	validation_0-mae:3.14673
# [204]	validation_0-mae:3.14292
# [205]	validation_0-mae:3.14264
# [206]	validation_0-mae:3.14264
# [207]	validation_0-mae:3.14264
# [208]	validation_0-mae:3.13314
# [209]	validation_0-mae:3.13314
# [210]	validation_0-mae:3.13871
# [211]	validation_0-mae:3.13872
# [212]	validation_0-mae:3.13858
# [213]	validation_0-mae:3.13858
# [214]	validation_0-mae:3.13840
# [215]	validation_0-mae:3.13840
# [216]	validation_0-mae:3.13530
# [217]	validation_0-mae:3.14601
# [218]	validation_0-mae:3.14616
# [219]	validation_0-mae:3.14616
# [220]	validation_0-mae:3.14929
# [221]	validation_0-mae:3.14929
# [222]	validation_0-mae:3.14929
# [223]	validation_0-mae:3.14903
# [224]	validation_0-mae:3.14903
# [225]	validation_0-mae:3.14903
# [226]	validation_0-mae:3.14921
# [227]	validation_0-mae:3.14921
# [228]	validation_0-mae:3.15807
# [229]	validation_0-mae:3.15843
# [230]	validation_0-mae:3.15843
# [231]	validation_0-mae:3.17560
# [232]	validation_0-mae:3.16844
# [233]	validation_0-mae:3.16844
# [234]	validation_0-mae:3.17774
# [235]	validation_0-mae:3.17774
# [236]	validation_0-mae:3.17774
# [237]	validation_0-mae:3.17828
# [238]	validation_0-mae:3.17796
# [239]	validation_0-mae:3.17796
# [240]	validation_0-mae:3.17796
# [241]	validation_0-mae:3.17858
# [242]	validation_0-mae:3.17850
# [243]	validation_0-mae:3.18223
# [244]	validation_0-mae:3.15098
# [245]	validation_0-mae:3.14120
# [246]	validation_0-mae:3.14120
# [247]	validation_0-mae:3.14120
# [248]	validation_0-mae:3.14120
# [249]	validation_0-mae:3.14120
# [250]	validation_0-mae:3.14120
# [251]	validation_0-mae:3.14120
# [252]	validation_0-mae:3.14120
# [253]	validation_0-mae:3.15250
# [254]	validation_0-mae:3.15250
# [255]	validation_0-mae:3.14361
# [256]	validation_0-mae:3.15792
# [257]	validation_0-mae:3.15792
# [258]	validation_0-mae:3.15792
# [259]	validation_0-mae:3.15792
# [260]	validation_0-mae:3.17594
# [261]	validation_0-mae:3.20234
# [262]	validation_0-mae:3.17463
# [263]	validation_0-mae:3.17463
# [264]	validation_0-mae:3.17552
# [265]	validation_0-mae:3.21194
# [266]	validation_0-mae:3.21209
# [267]	validation_0-mae:3.19657
# [268]	validation_0-mae:3.19657
# [269]	validation_0-mae:3.19618
# [270]	validation_0-mae:3.19618
# [271]	validation_0-mae:3.19618
# [272]	validation_0-mae:3.19618
# [273]	validation_0-mae:3.19647
# [274]	validation_0-mae:3.19647
# [275]	validation_0-mae:3.19654
# [276]	validation_0-mae:3.20872
# [277]	validation_0-mae:3.20769
# [278]	validation_0-mae:3.19670
# [279]	validation_0-mae:3.19697
# [280]	validation_0-mae:3.19697
# [281]	validation_0-mae:3.19697
# [282]	validation_0-mae:3.19698
# [283]	validation_0-mae:3.19698
# [284]	validation_0-mae:3.20446
# [285]	validation_0-mae:3.22969
# [286]	validation_0-mae:3.22969
# [287]	validation_0-mae:3.21777
# [288]	validation_0-mae:3.21777
# [289]	validation_0-mae:3.22677
# [290]	validation_0-mae:3.22152
# [291]	validation_0-mae:3.22518
# [292]	validation_0-mae:3.22587
# [293]	validation_0-mae:3.22587
# [294]	validation_0-mae:3.22863
# [295]	validation_0-mae:3.23214
# [296]	validation_0-mae:3.22016
# [297]	validation_0-mae:3.22468
# [298]	validation_0-mae:3.26142
# [299]	validation_0-mae:3.26055
# [300]	validation_0-mae:3.25933
# [301]	validation_0-mae:3.25933
# [302]	validation_0-mae:3.25642
# [303]	validation_0-mae:3.25642
# [304]	validation_0-mae:3.25642
# [305]	validation_0-mae:3.26260
# [306]	validation_0-mae:3.27962
# [307]	validation_0-mae:3.27962
# [308]	validation_0-mae:3.27962
# [309]	validation_0-mae:3.27962
# [310]	validation_0-mae:3.27962
# [311]	validation_0-mae:3.27745
# [312]	validation_0-mae:3.27745
# [313]	validation_0-mae:3.28002
# [314]	validation_0-mae:3.28002
# [315]	validation_0-mae:3.28002
# [316]	validation_0-mae:3.28767
# [317]	validation_0-mae:3.28776
# [318]	validation_0-mae:3.28776
# [319]	validation_0-mae:3.28776
# [320]	validation_0-mae:3.28877
# [321]	validation_0-mae:3.28749
# [322]	validation_0-mae:3.28749
# [323]	validation_0-mae:3.28264
# [324]	validation_0-mae:3.29737
# [325]	validation_0-mae:3.32561
# [326]	validation_0-mae:3.32561
# [327]	validation_0-mae:3.32553
# [328]	validation_0-mae:3.32563
# [329]	validation_0-mae:3.32522
# [330]	validation_0-mae:3.32522
# [331]	validation_0-mae:3.32522
# [332]	validation_0-mae:3.32556
# [333]	validation_0-mae:3.32556
# [334]	validation_0-mae:3.32808
# [335]	validation_0-mae:3.35188
# [336]	validation_0-mae:3.35188
# [337]	validation_0-mae:3.35188
# [338]	validation_0-mae:3.34417
# [339]	validation_0-mae:3.34417
# [340]	validation_0-mae:3.37672
# [341]	validation_0-mae:3.37672
# [342]	validation_0-mae:3.37672
# [343]	validation_0-mae:3.37845
# [344]	validation_0-mae:3.37247
# [345]	validation_0-mae:3.37187
# [346]	validation_0-mae:3.37187
# [347]	validation_0-mae:3.37187
# [348]	validation_0-mae:3.36991
# [349]	validation_0-mae:3.36951
# [350]	validation_0-mae:3.36951
# [351]	validation_0-mae:3.36957
# [352]	validation_0-mae:3.37106
# [353]	validation_0-mae:3.37106
# [354]	validation_0-mae:3.37106
# [355]	validation_0-mae:3.37106
# [356]	validation_0-mae:3.37107
# [357]	validation_0-mae:3.37107
# [358]	validation_0-mae:3.37048
# [359]	validation_0-mae:3.37015
# [360]	validation_0-mae:3.37010
# [361]	validation_0-mae:3.37016
# [362]	validation_0-mae:3.36196
# [363]	validation_0-mae:3.36205
# [364]	validation_0-mae:3.35461
# [365]	validation_0-mae:3.35460
# [366]	validation_0-mae:3.35460
# [367]	validation_0-mae:3.35460
# [368]	validation_0-mae:3.35400
# [369]	validation_0-mae:3.35488
# [370]	validation_0-mae:3.35488
# [371]	validation_0-mae:3.37892
# [372]	validation_0-mae:3.37892
# [373]	validation_0-mae:3.36791
# [374]	validation_0-mae:3.36791
# [375]	validation_0-mae:3.37844
# [376]	validation_0-mae:3.37935
# [377]	validation_0-mae:3.37974
# [378]	validation_0-mae:3.38019
# [379]	validation_0-mae:3.38019
# [380]	validation_0-mae:3.37864
# [381]	validation_0-mae:3.37858
# [382]	validation_0-mae:3.37493
# [383]	validation_0-mae:3.35594
# [384]	validation_0-mae:3.35100
# [385]	validation_0-mae:3.36375
# [386]	validation_0-mae:3.36375
# [387]	validation_0-mae:3.36375
# [388]	validation_0-mae:3.36375
# [389]	validation_0-mae:3.36269
# [390]	validation_0-mae:3.36111
# [391]	validation_0-mae:3.36084
# [392]	validation_0-mae:3.36108
# [393]	validation_0-mae:3.36195
# [394]	validation_0-mae:3.33604
# [395]	validation_0-mae:3.33569
# [396]	validation_0-mae:3.33569
# [397]	validation_0-mae:3.33645
# [398]	validation_0-mae:3.32754
# [399]	validation_0-mae:3.32919
# [400]	validation_0-mae:3.32919
# [401]	validation_0-mae:3.32919
# [402]	validation_0-mae:3.32917
# [403]	validation_0-mae:3.32909
# [404]	validation_0-mae:3.32909
# [405]	validation_0-mae:3.33033
# [406]	validation_0-mae:3.33033
# [407]	validation_0-mae:3.32917
# [408]	validation_0-mae:3.32925
# [409]	validation_0-mae:3.30149
# [410]	validation_0-mae:3.30149
# [411]	validation_0-mae:3.30149
# [412]	validation_0-mae:3.30131
# [413]	validation_0-mae:3.28564
# [414]	validation_0-mae:3.27890
# [415]	validation_0-mae:3.27890
# [416]	validation_0-mae:3.27890
# [417]	validation_0-mae:3.28014
# [418]	validation_0-mae:3.28014
# [419]	validation_0-mae:3.28068
# [420]	validation_0-mae:3.28185
# [421]	validation_0-mae:3.28185
# [422]	validation_0-mae:3.28293
# [423]	validation_0-mae:3.27929
# [424]	validation_0-mae:3.28819
# [425]	validation_0-mae:3.28819
# [426]	validation_0-mae:3.29684
# [427]	validation_0-mae:3.29684
# [428]	validation_0-mae:3.29551
# [429]	validation_0-mae:3.28825
# [430]	validation_0-mae:3.28625
# [431]	validation_0-mae:3.28526
# [432]	validation_0-mae:3.28526
# [433]	validation_0-mae:3.28526
# [434]	validation_0-mae:3.28526
# [435]	validation_0-mae:3.28526
# [436]	validation_0-mae:3.28279
# [437]	validation_0-mae:3.28279
# [438]	validation_0-mae:3.28279
# [439]	validation_0-mae:3.28284
# [440]	validation_0-mae:3.28959
# [441]	validation_0-mae:3.28234
# [442]	validation_0-mae:3.27766
# [443]	validation_0-mae:3.27766
# [444]	validation_0-mae:3.27684
# [445]	validation_0-mae:3.27795
# [446]	validation_0-mae:3.27776
# [447]	validation_0-mae:3.27793
# [448]	validation_0-mae:3.27888
# [449]	validation_0-mae:3.27888
# [450]	validation_0-mae:3.27888
# [451]	validation_0-mae:3.27888
# [452]	validation_0-mae:3.27888
# [453]	validation_0-mae:3.28045
# [454]	validation_0-mae:3.28162
# [455]	validation_0-mae:3.28479
# [456]	validation_0-mae:3.28479
# [457]	validation_0-mae:3.28479
# [458]	validation_0-mae:3.28799
# [459]	validation_0-mae:3.28759
# [460]	validation_0-mae:3.29049
# [461]	validation_0-mae:3.29616
# [462]	validation_0-mae:3.30691
# [463]	validation_0-mae:3.31015
# [464]	validation_0-mae:3.31015
# [465]	validation_0-mae:3.30679
# [466]	validation_0-mae:3.30696
# [467]	validation_0-mae:3.30915
# [468]	validation_0-mae:3.30928
# [469]	validation_0-mae:3.30928
# [470]	validation_0-mae:3.30928
# [471]	validation_0-mae:3.31152
# [472]	validation_0-mae:3.31038
# [473]	validation_0-mae:3.30892
# [474]	validation_0-mae:3.30823
# [475]	validation_0-mae:3.30823
# [476]	validation_0-mae:3.29165
# [477]	validation_0-mae:3.29165
# [478]	validation_0-mae:3.29165
# [479]	validation_0-mae:3.30783
# [480]	validation_0-mae:3.30772
# [481]	validation_0-mae:3.30772
# [482]	validation_0-mae:3.30772
# [483]	validation_0-mae:3.30641
# [484]	validation_0-mae:3.30641
# [485]	validation_0-mae:3.29853
# [486]	validation_0-mae:3.29853
# [487]	validation_0-mae:3.29233
# [488]	validation_0-mae:3.29090
# [489]	validation_0-mae:3.29906
# [490]	validation_0-mae:3.29906
# [491]	validation_0-mae:3.29906
# [492]	validation_0-mae:3.29532
# [493]	validation_0-mae:3.29896
# [494]	validation_0-mae:3.29856
# [495]	validation_0-mae:3.29856
# [496]	validation_0-mae:3.29856
# [497]	validation_0-mae:3.29856
# [498]	validation_0-mae:3.30318
# [499]	validation_0-mae:3.30318
# [500]	validation_0-mae:3.30262
# [501]	validation_0-mae:3.30262
# [502]	validation_0-mae:3.32596
# [503]	validation_0-mae:3.32587
# [504]	validation_0-mae:3.32919
# [505]	validation_0-mae:3.32886
# [506]	validation_0-mae:3.32947
# [507]	validation_0-mae:3.32947
# [508]	validation_0-mae:3.32947
# [509]	validation_0-mae:3.34506
# [510]	validation_0-mae:3.34506
# [511]	validation_0-mae:3.34616
# [512]	validation_0-mae:3.34591
# [513]	validation_0-mae:3.34591
# [514]	validation_0-mae:3.34574
# [515]	validation_0-mae:3.34574
# [516]	validation_0-mae:3.34991
# [517]	validation_0-mae:3.34983
# [518]	validation_0-mae:3.34983
# [519]	validation_0-mae:3.34899
# [520]	validation_0-mae:3.34864
# [521]	validation_0-mae:3.34370
# [522]	validation_0-mae:3.34339
# [523]	validation_0-mae:3.34589
# [524]	validation_0-mae:3.34657
# [525]	validation_0-mae:3.34348
# [526]	validation_0-mae:3.34760
# [527]	validation_0-mae:3.34760
# [528]	validation_0-mae:3.33863
# [529]	validation_0-mae:3.33631
# [530]	validation_0-mae:3.33631
# [531]	validation_0-mae:3.33631
# [532]	validation_0-mae:3.33631
# [533]	validation_0-mae:3.33617
# [534]	validation_0-mae:3.33669
# [535]	validation_0-mae:3.33222
# [536]	validation_0-mae:3.33242
# [537]	validation_0-mae:3.33040
# [538]	validation_0-mae:3.33040
# [539]	validation_0-mae:3.33071
# [540]	validation_0-mae:3.34094
# [541]	validation_0-mae:3.34973
# [542]	validation_0-mae:3.34670
# [543]	validation_0-mae:3.34628
# [544]	validation_0-mae:3.35297
# [545]	validation_0-mae:3.35299
# [546]	validation_0-mae:3.33566
# [547]	validation_0-mae:3.33444
# [548]	validation_0-mae:3.33438
# [549]	validation_0-mae:3.33547
# [550]	validation_0-mae:3.34169
# [551]	validation_0-mae:3.34169
# [552]	validation_0-mae:3.34169
# [553]	validation_0-mae:3.33936
# [554]	validation_0-mae:3.33806
# [555]	validation_0-mae:3.32297
# [556]	validation_0-mae:3.32297
# [557]	validation_0-mae:3.32305
# [558]	validation_0-mae:3.32305
# [559]	validation_0-mae:3.33285
# [560]	validation_0-mae:3.33285
# [561]	validation_0-mae:3.33399
# [562]	validation_0-mae:3.33104
# [563]	validation_0-mae:3.33104
# [564]	validation_0-mae:3.32721
# [565]	validation_0-mae:3.32771
# [566]	validation_0-mae:3.32771
# [567]	validation_0-mae:3.32433
# [568]	validation_0-mae:3.33482
# [569]	validation_0-mae:3.33673
# [570]	validation_0-mae:3.33709
# [571]	validation_0-mae:3.33709
# [572]	validation_0-mae:3.33709
# [573]	validation_0-mae:3.33925
# [574]	validation_0-mae:3.33925
# [575]	validation_0-mae:3.38568
# [576]	validation_0-mae:3.39271
# [577]	validation_0-mae:3.39971
# [578]	validation_0-mae:3.39971
# [579]	validation_0-mae:3.39972
# [580]	validation_0-mae:3.40397
# [581]	validation_0-mae:3.40566
# [582]	validation_0-mae:3.40711
# [583]	validation_0-mae:3.40711
# [584]	validation_0-mae:3.40296
# [585]	validation_0-mae:3.40378
# [586]	validation_0-mae:3.41013
# [587]	validation_0-mae:3.41092
# [588]	validation_0-mae:3.40586
# [589]	validation_0-mae:3.40569
# [590]	validation_0-mae:3.41239
# [591]	validation_0-mae:3.41196
# [592]	validation_0-mae:3.41196
# [593]	validation_0-mae:3.41233
# [594]	validation_0-mae:3.41237
# [595]	validation_0-mae:3.41237
# [596]	validation_0-mae:3.41237
# [597]	validation_0-mae:3.41237
# [598]	validation_0-mae:3.41237
# [599]	validation_0-mae:3.41515
# [600]	validation_0-mae:3.41515
# [601]	validation_0-mae:3.41515
# [602]	validation_0-mae:3.41515
# [603]	validation_0-mae:3.41515
# [604]	validation_0-mae:3.41515
# [605]	validation_0-mae:3.41681
# [606]	validation_0-mae:3.41681
# [607]	validation_0-mae:3.41681
# [608]	validation_0-mae:3.41681
# [609]	validation_0-mae:3.41125
# [610]	validation_0-mae:3.41299
# [611]	validation_0-mae:3.41299
# [612]	validation_0-mae:3.44630
# [613]	validation_0-mae:3.43998
# [614]	validation_0-mae:3.44262
# [615]	validation_0-mae:3.44080
# [616]	validation_0-mae:3.45251
# [617]	validation_0-mae:3.45148
# [618]	validation_0-mae:3.45148
# [619]	validation_0-mae:3.47733
# [620]	validation_0-mae:3.48847
# [621]	validation_0-mae:3.48847
# [622]	validation_0-mae:3.48007
# [623]	validation_0-mae:3.48007
# [624]	validation_0-mae:3.48008
# [625]	validation_0-mae:3.49527
# [626]	validation_0-mae:3.49527
# [627]	validation_0-mae:3.49413
# [628]	validation_0-mae:3.49413
# [629]	validation_0-mae:3.49148
# [630]	validation_0-mae:3.49211
# [631]	validation_0-mae:3.49211
# [632]	validation_0-mae:3.48935
# [633]	validation_0-mae:3.48911
# [634]	validation_0-mae:3.49465
# [635]	validation_0-mae:3.49448
# [636]	validation_0-mae:3.49433
# [637]	validation_0-mae:3.49433
# [638]	validation_0-mae:3.49433
# [639]	validation_0-mae:3.49433
# [640]	validation_0-mae:3.49433
# [641]	validation_0-mae:3.49644
# [642]	validation_0-mae:3.49585
# [643]	validation_0-mae:3.49585
# [644]	validation_0-mae:3.49677
# [645]	validation_0-mae:3.49790
# [646]	validation_0-mae:3.48092
# [647]	validation_0-mae:3.48362
# [648]	validation_0-mae:3.48362
# [649]	validation_0-mae:3.48362
# [650]	validation_0-mae:3.48362
# [651]	validation_0-mae:3.48401
# [652]	validation_0-mae:3.47805
# [653]	validation_0-mae:3.47805
# [654]	validation_0-mae:3.47709
# [655]	validation_0-mae:3.47837
# [656]	validation_0-mae:3.47809
# [657]	validation_0-mae:3.47809
# [658]	validation_0-mae:3.47807
# [659]	validation_0-mae:3.47807
# [660]	validation_0-mae:3.47918
# [661]	validation_0-mae:3.47920
# [662]	validation_0-mae:3.48661
# [663]	validation_0-mae:3.49365
# [664]	validation_0-mae:3.49608
# [665]	validation_0-mae:3.49426
# [666]	validation_0-mae:3.49426
# [667]	validation_0-mae:3.49390
# [668]	validation_0-mae:3.49390
# [669]	validation_0-mae:3.49390
# [670]	validation_0-mae:3.51240
# [671]	validation_0-mae:3.51241
# [672]	validation_0-mae:3.51241
# [673]	validation_0-mae:3.51105
# [674]	validation_0-mae:3.51105
# [675]	validation_0-mae:3.51025
# [676]	validation_0-mae:3.52122
# [677]	validation_0-mae:3.55206
# [678]	validation_0-mae:3.56735
# [679]	validation_0-mae:3.56682
# [680]	validation_0-mae:3.56682
# [681]	validation_0-mae:3.56682
# [682]	validation_0-mae:3.56682
# [683]	validation_0-mae:3.56682
# [684]	validation_0-mae:3.56682
# [685]	validation_0-mae:3.56693
# [686]	validation_0-mae:3.56693
# [687]	validation_0-mae:3.56693
# [688]	validation_0-mae:3.56750
# [689]	validation_0-mae:3.56750
# [690]	validation_0-mae:3.56750
# [691]	validation_0-mae:3.56750
# [692]	validation_0-mae:3.57840
# [693]	validation_0-mae:3.57840
# [694]	validation_0-mae:3.58401
# [695]	validation_0-mae:3.58401
# [696]	validation_0-mae:3.58401
# [697]	validation_0-mae:3.58401
# [698]	validation_0-mae:3.58405
# [699]	validation_0-mae:3.58405
# [700]	validation_0-mae:3.58230
# [701]	validation_0-mae:3.58518
# [702]	validation_0-mae:3.61331
# [703]	validation_0-mae:3.61213
# [704]	validation_0-mae:3.60878
# [705]	validation_0-mae:3.60878
# [706]	validation_0-mae:3.60668
# [707]	validation_0-mae:3.62060
# [708]	validation_0-mae:3.62060
# [709]	validation_0-mae:3.62060
# [710]	validation_0-mae:3.63877
# [711]	validation_0-mae:3.63877
# [712]	validation_0-mae:3.63323
# [713]	validation_0-mae:3.63328
# [714]	validation_0-mae:3.63108
# [715]	validation_0-mae:3.63108
# [716]	validation_0-mae:3.63543
# [717]	validation_0-mae:3.64548
# [718]	validation_0-mae:3.64548
# [719]	validation_0-mae:3.64548
# [720]	validation_0-mae:3.64548
# [721]	validation_0-mae:3.66287
# [722]	validation_0-mae:3.67425
# [723]	validation_0-mae:3.67425
# [724]	validation_0-mae:3.67425
# [725]	validation_0-mae:3.66152
# [726]	validation_0-mae:3.68213
# [727]	validation_0-mae:3.68370
# [728]	validation_0-mae:3.66921
# [729]	validation_0-mae:3.66923
# [730]	validation_0-mae:3.66923
# [731]	validation_0-mae:3.67621
# [732]	validation_0-mae:3.67621
# [733]	validation_0-mae:3.67621
# [734]	validation_0-mae:3.67621
# [735]	validation_0-mae:3.67621
# [736]	validation_0-mae:3.67621
# [737]	validation_0-mae:3.67621
# [738]	validation_0-mae:3.67621
# [739]	validation_0-mae:3.67621
# [740]	validation_0-mae:3.67345
# [741]	validation_0-mae:3.67490
# [742]	validation_0-mae:3.68672
# [743]	validation_0-mae:3.68733
# [744]	validation_0-mae:3.68733
# [745]	validation_0-mae:3.68733
# [746]	validation_0-mae:3.70153
# [747]	validation_0-mae:3.70032
# [748]	validation_0-mae:3.70032
# [749]	validation_0-mae:3.70032
# [750]	validation_0-mae:3.70032
# [751]	validation_0-mae:3.70027
# [752]	validation_0-mae:3.69765
# [753]	validation_0-mae:3.70848
# [754]	validation_0-mae:3.70257
# [755]	validation_0-mae:3.69888
# [756]	validation_0-mae:3.70311
# [757]	validation_0-mae:3.70240
# [758]	validation_0-mae:3.70043
# [759]	validation_0-mae:3.69876
# [760]	validation_0-mae:3.69220
# [761]	validation_0-mae:3.69224
# [762]	validation_0-mae:3.69914
# [763]	validation_0-mae:3.69887
# [764]	validation_0-mae:3.69887
# [765]	validation_0-mae:3.70829
# [766]	validation_0-mae:3.71862
# [767]	validation_0-mae:3.71862
# [768]	validation_0-mae:3.71862
# [769]	validation_0-mae:3.71889
# [770]	validation_0-mae:3.71889
# [771]	validation_0-mae:3.71889
# [772]	validation_0-mae:3.71932
# [773]	validation_0-mae:3.69254
# [774]	validation_0-mae:3.69242
# [775]	validation_0-mae:3.69242
# [776]	validation_0-mae:3.69088
# [777]	validation_0-mae:3.68451
# [778]	validation_0-mae:3.68451
# [779]	validation_0-mae:3.68451
# [780]	validation_0-mae:3.66101
# [781]	validation_0-mae:3.66087
# [782]	validation_0-mae:3.66087
# [783]	validation_0-mae:3.65554
# [784]	validation_0-mae:3.65552
# [785]	validation_0-mae:3.65457
# [786]	validation_0-mae:3.65542
# [787]	validation_0-mae:3.65445
# [788]	validation_0-mae:3.65441
# [789]	validation_0-mae:3.65404
# [790]	validation_0-mae:3.65404
# [791]	validation_0-mae:3.65404
# [792]	validation_0-mae:3.65474
# [793]	validation_0-mae:3.65474
# [794]	validation_0-mae:3.65474
# [795]	validation_0-mae:3.65474
# [796]	validation_0-mae:3.65164
# [797]	validation_0-mae:3.65164
# [798]	validation_0-mae:3.66017
# [799]	validation_0-mae:3.66130
# [800]	validation_0-mae:3.66130
# [801]	validation_0-mae:3.66130
# [802]	validation_0-mae:3.66130
# [803]	validation_0-mae:3.67796
# [804]	validation_0-mae:3.67732
# [805]	validation_0-mae:3.67732
# [806]	validation_0-mae:3.67763
# [807]	validation_0-mae:3.67559
# [808]	validation_0-mae:3.67559
# [809]	validation_0-mae:3.67559
# [810]	validation_0-mae:3.67651
# [811]	validation_0-mae:3.67651
# [812]	validation_0-mae:3.67516
# [813]	validation_0-mae:3.67516
# [814]	validation_0-mae:3.67516
# [815]	validation_0-mae:3.72211
# [816]	validation_0-mae:3.72211
# [817]	validation_0-mae:3.72211
# [818]	validation_0-mae:3.72112
# [819]	validation_0-mae:3.71982
# [820]	validation_0-mae:3.71703
# [821]	validation_0-mae:3.71364
# [822]	validation_0-mae:3.71364
# [823]	validation_0-mae:3.72773
# [824]	validation_0-mae:3.72900
# [825]	validation_0-mae:3.72895
# [826]	validation_0-mae:3.72895
# [827]	validation_0-mae:3.72826
# [828]	validation_0-mae:3.72826
# [829]	validation_0-mae:3.72828
# [830]	validation_0-mae:3.73085
# [831]	validation_0-mae:3.73135
# [832]	validation_0-mae:3.73135
# [833]	validation_0-mae:3.73021
# [834]	validation_0-mae:3.72593
# [835]	validation_0-mae:3.72370
# [836]	validation_0-mae:3.72370
# [837]	validation_0-mae:3.72370
# [838]	validation_0-mae:3.72134
# [839]	validation_0-mae:3.71991
# [840]	validation_0-mae:3.71895
# [841]	validation_0-mae:3.71895
# [842]	validation_0-mae:3.71895
# [843]	validation_0-mae:3.72233
# [844]	validation_0-mae:3.72104
# [845]	validation_0-mae:3.71998
# [846]	validation_0-mae:3.71998
# [847]	validation_0-mae:3.71998
# [848]	validation_0-mae:3.72631
# [849]	validation_0-mae:3.72631
# [850]	validation_0-mae:3.73748
# [851]	validation_0-mae:3.73748
# [852]	validation_0-mae:3.73621
# [853]	validation_0-mae:3.73621
# [854]	validation_0-mae:3.73621
# [855]	validation_0-mae:3.73626
# [856]	validation_0-mae:3.74431
# [857]	validation_0-mae:3.74848
# [858]	validation_0-mae:3.74848
# [859]	validation_0-mae:3.74848
# [860]	validation_0-mae:3.74848
# [861]	validation_0-mae:3.74848
# [862]	validation_0-mae:3.77068
# [863]	validation_0-mae:3.77068
# [864]	validation_0-mae:3.80129
# [865]	validation_0-mae:3.80129
# [866]	validation_0-mae:3.80129
# [867]	validation_0-mae:3.80129
# [868]	validation_0-mae:3.80044
# [869]	validation_0-mae:3.79963
# [870]	validation_0-mae:3.79965
# [871]	validation_0-mae:3.79965
# [872]	validation_0-mae:3.79901
# [873]	validation_0-mae:3.79666
# [874]	validation_0-mae:3.79666
# [875]	validation_0-mae:3.79666
# [876]	validation_0-mae:3.79614
# [877]	validation_0-mae:3.79492
# [878]	validation_0-mae:3.79515
# [879]	validation_0-mae:3.80610
# [880]	validation_0-mae:3.80610
# [881]	validation_0-mae:3.80610
# [882]	validation_0-mae:3.80610
# [883]	validation_0-mae:3.79670
# [884]	validation_0-mae:3.79697
# [885]	validation_0-mae:3.79697
# [886]	validation_0-mae:3.79697
# [887]	validation_0-mae:3.79466
# [888]	validation_0-mae:3.79826
# [889]	validation_0-mae:3.79854
# [890]	validation_0-mae:3.79854
# [891]	validation_0-mae:3.79854
# [892]	validation_0-mae:3.79267
# [893]	validation_0-mae:3.79267
# [894]	validation_0-mae:3.78822
# [895]	validation_0-mae:3.83586
# [896]	validation_0-mae:3.83586
# [897]	validation_0-mae:3.83964
# [898]	validation_0-mae:3.83711
# [899]	validation_0-mae:3.84318
# [900]	validation_0-mae:3.84246
# [901]	validation_0-mae:3.84245
# [902]	validation_0-mae:3.84245
# [903]	validation_0-mae:3.84442
# [904]	validation_0-mae:3.84358
# [905]	validation_0-mae:3.84527
# [906]	validation_0-mae:3.84020
# [907]	validation_0-mae:3.84420
# [908]	validation_0-mae:3.84420
# [909]	validation_0-mae:3.84420
# [910]	validation_0-mae:3.84420
# [911]	validation_0-mae:3.85892
# [912]	validation_0-mae:3.85892
# [913]	validation_0-mae:3.87312
# [914]	validation_0-mae:3.87312
# [915]	validation_0-mae:3.87312
# [916]	validation_0-mae:3.87002
# [917]	validation_0-mae:3.86737
# [918]	validation_0-mae:3.86737
# [919]	validation_0-mae:3.86346
# [920]	validation_0-mae:3.85848
# [921]	validation_0-mae:3.85401
# [922]	validation_0-mae:3.85393
# [923]	validation_0-mae:3.85393
# [924]	validation_0-mae:3.86472
# [925]	validation_0-mae:3.86419
# [926]	validation_0-mae:3.86363
# [927]	validation_0-mae:3.86363
# [928]	validation_0-mae:3.86769
# [929]	validation_0-mae:3.86467
# [930]	validation_0-mae:3.86467
# [931]	validation_0-mae:3.86353
# [932]	validation_0-mae:3.86285
# [933]	validation_0-mae:3.86285
# [934]	validation_0-mae:3.86609
# [935]	validation_0-mae:3.86609
# [936]	validation_0-mae:3.86536
# [937]	validation_0-mae:3.87104
# [938]	validation_0-mae:3.87275
# [939]	validation_0-mae:3.87292
# [940]	validation_0-mae:3.87342
# [941]	validation_0-mae:3.88381
# [942]	validation_0-mae:3.88382
# [943]	validation_0-mae:3.88382
# [944]	validation_0-mae:3.88382
# [945]	validation_0-mae:3.87203
# [946]	validation_0-mae:3.86932
# [947]	validation_0-mae:3.86932
# [948]	validation_0-mae:3.86932
# [949]	validation_0-mae:3.87306
# [950]	validation_0-mae:3.87524
# [951]	validation_0-mae:3.87301
# [952]	validation_0-mae:3.87318
# [953]	validation_0-mae:3.87315
# [954]	validation_0-mae:3.87260
# [955]	validation_0-mae:3.87275
# [956]	validation_0-mae:3.87201
# [957]	validation_0-mae:3.86854
# [958]	validation_0-mae:3.86854
# [959]	validation_0-mae:3.86088
# [960]	validation_0-mae:3.85667
# [961]	validation_0-mae:3.86855
# [962]	validation_0-mae:3.86856
# [963]	validation_0-mae:3.86827
# [964]	validation_0-mae:3.86827
# [965]	validation_0-mae:3.86413
# [966]	validation_0-mae:3.86621
# [967]	validation_0-mae:3.86621
# [968]	validation_0-mae:3.86566
# [969]	validation_0-mae:3.86566
# [970]	validation_0-mae:3.86526
# [971]	validation_0-mae:3.86529
# [972]	validation_0-mae:3.87052
# [973]	validation_0-mae:3.87052
# [974]	validation_0-mae:3.87088
# [975]	validation_0-mae:3.87088
# [976]	validation_0-mae:3.87354
# [977]	validation_0-mae:3.87354
# [978]	validation_0-mae:3.87324
# [979]	validation_0-mae:3.86946
# [980]	validation_0-mae:3.86946
# [981]	validation_0-mae:3.87263
# [982]	validation_0-mae:3.87263
# [983]	validation_0-mae:3.87284
# [984]	validation_0-mae:3.87320
# [985]	validation_0-mae:3.87320
# [986]	validation_0-mae:3.87324
# [987]	validation_0-mae:3.87418
# [988]	validation_0-mae:3.87366
# [989]	validation_0-mae:3.87366
# [990]	validation_0-mae:3.87277
# [991]	validation_0-mae:3.87200
# [992]	validation_0-mae:3.87200
# [993]	validation_0-mae:3.86858
# [994]	validation_0-mae:3.86858
# [995]	validation_0-mae:3.86857
# [996]	validation_0-mae:3.86880
# [997]	validation_0-mae:3.87393
# [998]	validation_0-mae:3.87408
# [999]	validation_0-mae:3.87427
# [1000]	validation_0-mae:3.87837
# [1001]	validation_0-mae:3.87907
# [1002]	validation_0-mae:3.87907
# [1003]	validation_0-mae:3.87907
# [1004]	validation_0-mae:3.90103
# [1005]	validation_0-mae:3.90103
# [1006]	validation_0-mae:3.90103
# [1007]	validation_0-mae:3.89401
# [1008]	validation_0-mae:3.89238
# [1009]	validation_0-mae:3.89238
# [1010]	validation_0-mae:3.91187
# [1011]	validation_0-mae:3.91187
# [1012]	validation_0-mae:3.91215
# [1013]	validation_0-mae:3.91215
# [1014]	validation_0-mae:3.91215
# [1015]	validation_0-mae:3.92649
# [1016]	validation_0-mae:3.93514
# [1017]	validation_0-mae:3.93514
# [1018]	validation_0-mae:3.93826
# [1019]	validation_0-mae:3.91630
# [1020]	validation_0-mae:3.91443
# [1021]	validation_0-mae:3.91420
# [1022]	validation_0-mae:3.91020
# [1023]	validation_0-mae:3.91020
# [1024]	validation_0-mae:3.91020
# [1025]	validation_0-mae:3.91020
# [1026]	validation_0-mae:3.91020
# [1027]	validation_0-mae:3.90776
# [1028]	validation_0-mae:3.90781
# [1029]	validation_0-mae:3.90781
# [1030]	validation_0-mae:3.90799
# [1031]	validation_0-mae:3.90799
# [1032]	validation_0-mae:3.90799
# [1033]	validation_0-mae:3.90799
# [1034]	validation_0-mae:3.90852
# [1035]	validation_0-mae:3.90852
# [1036]	validation_0-mae:3.90852
# [1037]	validation_0-mae:3.90830
# [1038]	validation_0-mae:3.90830
# [1039]	validation_0-mae:3.90854
# [1040]	validation_0-mae:3.91293
# [1041]	validation_0-mae:3.89050
# [1042]	validation_0-mae:3.89050
# [1043]	validation_0-mae:3.89043
# [1044]	validation_0-mae:3.89043
# [1045]	validation_0-mae:3.89043
# [1046]	validation_0-mae:3.89417
# [1047]	validation_0-mae:3.89417
# [1048]	validation_0-mae:3.89417
# [1049]	validation_0-mae:3.89417
# [1050]	validation_0-mae:3.89417
# [1051]	validation_0-mae:3.89388
# [1052]	validation_0-mae:3.87595
# [1053]	validation_0-mae:3.87595
# [1054]	validation_0-mae:3.87595
# [1055]	validation_0-mae:3.87250
# [1056]	validation_0-mae:3.87318
# [1057]	validation_0-mae:3.87318
# [1058]	validation_0-mae:3.87399
# [1059]	validation_0-mae:3.87399
# [1060]	validation_0-mae:3.87993
# [1061]	validation_0-mae:3.87993
# [1062]	validation_0-mae:3.87993
# [1063]	validation_0-mae:3.87993
# [1064]	validation_0-mae:3.87993
# [1065]	validation_0-mae:3.87994
# [1066]	validation_0-mae:3.88251
# [1067]	validation_0-mae:3.88108
# [1068]	validation_0-mae:3.88108
# [1069]	validation_0-mae:3.88108
# [1070]	validation_0-mae:3.87945
# [1071]	validation_0-mae:3.87945
# [1072]	validation_0-mae:3.88193
# [1073]	validation_0-mae:3.88193
# [1074]	validation_0-mae:3.87868
# [1075]	validation_0-mae:3.87788
# [1076]	validation_0-mae:3.87788
# [1077]	validation_0-mae:3.87692
# [1078]	validation_0-mae:3.88224
# [1079]	validation_0-mae:3.88224
# [1080]	validation_0-mae:3.88363
# [1081]	validation_0-mae:3.88288
# [1082]	validation_0-mae:3.88385
# [1083]	validation_0-mae:3.89311
# [1084]	validation_0-mae:3.89189
# [1085]	validation_0-mae:3.89189
# [1086]	validation_0-mae:3.89188
# [1087]	validation_0-mae:3.89197
# [1088]	validation_0-mae:3.88756
# [1089]	validation_0-mae:3.88761
# [1090]	validation_0-mae:3.88802
# [1091]	validation_0-mae:3.88838
# [1092]	validation_0-mae:3.88827
# [1093]	validation_0-mae:3.88675
# [1094]	validation_0-mae:3.88671
# [1095]	validation_0-mae:3.88590
# [1096]	validation_0-mae:3.88584
# [1097]	validation_0-mae:3.88563
# [1098]	validation_0-mae:3.88836
# [1099]	validation_0-mae:3.88834
# [1100]	validation_0-mae:3.88854
# [1101]	validation_0-mae:3.88965
# [1102]	validation_0-mae:3.88965
# [1103]	validation_0-mae:3.88958
# [1104]	validation_0-mae:3.88958
# [1105]	validation_0-mae:3.89035
# [1106]	validation_0-mae:3.88265
# [1107]	validation_0-mae:3.87757
# [1108]	validation_0-mae:3.87880
# [1109]	validation_0-mae:3.87880
# [1110]	validation_0-mae:3.87676
# [1111]	validation_0-mae:3.87676
# [1112]	validation_0-mae:3.87676
# [1113]	validation_0-mae:3.87656
# [1114]	validation_0-mae:3.87656
# [1115]	validation_0-mae:3.87656
# [1116]	validation_0-mae:3.87234
# [1117]	validation_0-mae:3.87179
# [1118]	validation_0-mae:3.87179
# [1119]	validation_0-mae:3.87813
# [1120]	validation_0-mae:3.88355
# [1121]	validation_0-mae:3.88439
# [1122]	validation_0-mae:3.88312
# [1123]	validation_0-mae:3.88169
# [1124]	validation_0-mae:3.88145
# [1125]	validation_0-mae:3.88377
# [1126]	validation_0-mae:3.88302
# [1127]	validation_0-mae:3.88302
# [1128]	validation_0-mae:3.88408
# [1129]	validation_0-mae:3.88268
# [1130]	validation_0-mae:3.88298
# [1131]	validation_0-mae:3.88771
# [1132]	validation_0-mae:3.88950
# [1133]	validation_0-mae:3.88950
# [1134]	validation_0-mae:3.88987
# [1135]	validation_0-mae:3.88977
# [1136]	validation_0-mae:3.88877
# [1137]	validation_0-mae:3.88877
# [1138]	validation_0-mae:3.88877
# [1139]	validation_0-mae:3.88877
# [1140]	validation_0-mae:3.87890
# [1141]	validation_0-mae:3.87890
# [1142]	validation_0-mae:3.87892
# [1143]	validation_0-mae:3.87665
# [1144]	validation_0-mae:3.87719
# [1145]	validation_0-mae:3.87522
# [1146]	validation_0-mae:3.90133
# [1147]	validation_0-mae:3.90157
# [1148]	validation_0-mae:3.90148
# [1149]	validation_0-mae:3.90073
# [1150]	validation_0-mae:3.89125
# [1151]	validation_0-mae:3.87811
# [1152]	validation_0-mae:3.87811
# [1153]	validation_0-mae:3.87788
# [1154]	validation_0-mae:3.87788
# [1155]	validation_0-mae:3.87767
# [1156]	validation_0-mae:3.86849
# [1157]	validation_0-mae:3.86849
# [1158]	validation_0-mae:3.88741
# [1159]	validation_0-mae:3.88741
# [1160]	validation_0-mae:3.89374
# [1161]	validation_0-mae:3.89374
# [1162]	validation_0-mae:3.89173
# [1163]	validation_0-mae:3.88793
# [1164]	validation_0-mae:3.88794
# [1165]	validation_0-mae:3.88796
# [1166]	validation_0-mae:3.88693
# [1167]	validation_0-mae:3.90186
# [1168]	validation_0-mae:3.90082
# [1169]	validation_0-mae:3.90082
# [1170]	validation_0-mae:3.90082
# [1171]	validation_0-mae:3.90082
# [1172]	validation_0-mae:3.87117
# [1173]	validation_0-mae:3.87117
# [1174]	validation_0-mae:3.87117
# [1175]	validation_0-mae:3.87117
# [1176]	validation_0-mae:3.87258
# [1177]	validation_0-mae:3.87258
# [1178]	validation_0-mae:3.87100
# [1179]	validation_0-mae:3.87100
# [1180]	validation_0-mae:3.87059
# [1181]	validation_0-mae:3.87059
# [1182]	validation_0-mae:3.87059
# [1183]	validation_0-mae:3.87059
# [1184]	validation_0-mae:3.86833
# [1185]	validation_0-mae:3.86644
# [1186]	validation_0-mae:3.86712
# [1187]	validation_0-mae:3.90975
# [1188]	validation_0-mae:3.90763
# [1189]	validation_0-mae:3.90771
# [1190]	validation_0-mae:3.90671
# [1191]	validation_0-mae:3.90671
# [1192]	validation_0-mae:3.90409
# [1193]	validation_0-mae:3.89887
# [1194]	validation_0-mae:3.89887
# [1195]	validation_0-mae:3.89577
# [1196]	validation_0-mae:3.87685
# [1197]	validation_0-mae:3.87685
# [1198]	validation_0-mae:3.87746
# [1199]	validation_0-mae:3.88769
# [1200]	validation_0-mae:3.88659
# [1201]	validation_0-mae:3.88659
# [1202]	validation_0-mae:3.88641
# [1203]	validation_0-mae:3.88417
# [1204]	validation_0-mae:3.88485
# [1205]	validation_0-mae:3.88485
# [1206]	validation_0-mae:3.88485
# [1207]	validation_0-mae:3.88485
# [1208]	validation_0-mae:3.88387
# [1209]	validation_0-mae:3.88387
# [1210]	validation_0-mae:3.88387
# [1211]	validation_0-mae:3.88375
# [1212]	validation_0-mae:3.87996
# [1213]	validation_0-mae:3.87996
# [1214]	validation_0-mae:3.87951
# [1215]	validation_0-mae:3.86822
# [1216]	validation_0-mae:3.86833
# [1217]	validation_0-mae:3.86833
# [1218]	validation_0-mae:3.86715
# [1219]	validation_0-mae:3.86833
# [1220]	validation_0-mae:3.86833
# [1221]	validation_0-mae:3.86286
# [1222]	validation_0-mae:3.86371
# [1223]	validation_0-mae:3.86473
# [1224]	validation_0-mae:3.86413
# [1225]	validation_0-mae:3.86403
# [1226]	validation_0-mae:3.86403
# [1227]	validation_0-mae:3.86174
# [1228]	validation_0-mae:3.86367
# [1229]	validation_0-mae:3.86367
# [1230]	validation_0-mae:3.86407
# [1231]	validation_0-mae:3.86385
# [1232]	validation_0-mae:3.86385
# [1233]	validation_0-mae:3.86385
# [1234]	validation_0-mae:3.86385
# [1235]	validation_0-mae:3.86385
# [1236]	validation_0-mae:3.86385
# [1237]	validation_0-mae:3.86385
# [1238]	validation_0-mae:3.86385
# [1239]	validation_0-mae:3.83736
# [1240]	validation_0-mae:3.83622
# [1241]	validation_0-mae:3.84359
# [1242]	validation_0-mae:3.84668
# [1243]	validation_0-mae:3.84668
# [1244]	validation_0-mae:3.84668
# [1245]	validation_0-mae:3.84440
# [1246]	validation_0-mae:3.84446
# [1247]	validation_0-mae:3.84446
# [1248]	validation_0-mae:3.85846
# [1249]	validation_0-mae:3.85175
# [1250]	validation_0-mae:3.86683
# [1251]	validation_0-mae:3.86683
# [1252]	validation_0-mae:3.86691
# [1253]	validation_0-mae:3.89889
# [1254]	validation_0-mae:3.89889
# [1255]	validation_0-mae:3.89528
# [1256]	validation_0-mae:3.89550
# [1257]	validation_0-mae:3.89550
# [1258]	validation_0-mae:3.89550
# [1259]	validation_0-mae:3.89682
# [1260]	validation_0-mae:3.89471
# [1261]	validation_0-mae:3.89471
# [1262]	validation_0-mae:3.89443
# [1263]	validation_0-mae:3.89499
# [1264]	validation_0-mae:3.89499
# [1265]	validation_0-mae:3.89093
# [1266]	validation_0-mae:3.87741
# [1267]	validation_0-mae:3.87741
# [1268]	validation_0-mae:3.87741
# [1269]	validation_0-mae:3.87798
# [1270]	validation_0-mae:3.87798
# [1271]	validation_0-mae:3.87795
# [1272]	validation_0-mae:3.87948
# [1273]	validation_0-mae:3.88090
# [1274]	validation_0-mae:3.86343
# [1275]	validation_0-mae:3.86343
# [1276]	validation_0-mae:3.86343
# [1277]	validation_0-mae:3.86450
# [1278]	validation_0-mae:3.86450
# [1279]	validation_0-mae:3.85986
# [1280]	validation_0-mae:3.85870
# [1281]	validation_0-mae:3.85876
# [1282]	validation_0-mae:3.85844
# [1283]	validation_0-mae:3.84406
# [1284]	validation_0-mae:3.84381
# [1285]	validation_0-mae:3.84431
# [1286]	validation_0-mae:3.84125
# [1287]	validation_0-mae:3.84125
# [1288]	validation_0-mae:3.83941
# [1289]	validation_0-mae:3.83937
# [1290]	validation_0-mae:3.83937
# [1291]	validation_0-mae:3.83924
# [1292]	validation_0-mae:3.83942
# [1293]	validation_0-mae:3.83816
# [1294]	validation_0-mae:3.83909
# [1295]	validation_0-mae:3.83966
# [1296]	validation_0-mae:3.83641
# [1297]	validation_0-mae:3.83641
# [1298]	validation_0-mae:3.83641
# [1299]	validation_0-mae:3.83623
# [1300]	validation_0-mae:3.83623
# [1301]	validation_0-mae:3.83613
# [1302]	validation_0-mae:3.83613
# [1303]	validation_0-mae:3.83483
# [1304]	validation_0-mae:3.83423
# [1305]	validation_0-mae:3.82072
# [1306]	validation_0-mae:3.82072
# [1307]	validation_0-mae:3.85255
# [1308]	validation_0-mae:3.85255
# [1309]	validation_0-mae:3.85255
# [1310]	validation_0-mae:3.85255
# [1311]	validation_0-mae:3.84322
# [1312]	validation_0-mae:3.87422
# [1313]	validation_0-mae:3.87422
# [1314]	validation_0-mae:3.87406
# [1315]	validation_0-mae:3.87392
# [1316]	validation_0-mae:3.87392
# [1317]	validation_0-mae:3.87419
# [1318]	validation_0-mae:3.87419
# [1319]	validation_0-mae:3.87422
# [1320]	validation_0-mae:3.87422
# [1321]	validation_0-mae:3.87448
# [1322]	validation_0-mae:3.87572
# [1323]	validation_0-mae:3.87572
# [1324]	validation_0-mae:3.87572
# [1325]	validation_0-mae:3.87572
# [1326]	validation_0-mae:3.87381
# [1327]	validation_0-mae:3.88076
# [1328]	validation_0-mae:3.88016
# [1329]	validation_0-mae:3.87988
# [1330]	validation_0-mae:3.87891
# [1331]	validation_0-mae:3.87891
# [1332]	validation_0-mae:3.85039
# [1333]	validation_0-mae:3.85005
# [1334]	validation_0-mae:3.85078
# [1335]	validation_0-mae:3.85183
# [1336]	validation_0-mae:3.85183
# [1337]	validation_0-mae:3.85150
# [1338]	validation_0-mae:3.85150
# [1339]	validation_0-mae:3.85150
# [1340]	validation_0-mae:3.85150
# [1341]	validation_0-mae:3.85150
# [1342]	validation_0-mae:3.85150
# [1343]	validation_0-mae:3.85150
# [1344]	validation_0-mae:3.84801
# [1345]	validation_0-mae:3.84796
# [1346]	validation_0-mae:3.86057
# [1347]	validation_0-mae:3.86145
# [1348]	validation_0-mae:3.86164
# [1349]	validation_0-mae:3.86164
# [1350]	validation_0-mae:3.87288
# [1351]	validation_0-mae:3.87067
# [1352]	validation_0-mae:3.87067
# [1353]	validation_0-mae:3.86962
# [1354]	validation_0-mae:3.86962
# [1355]	validation_0-mae:3.86517
# [1356]	validation_0-mae:3.86486
# [1357]	validation_0-mae:3.86486
# [1358]	validation_0-mae:3.86400
# [1359]	validation_0-mae:3.86325
# [1360]	validation_0-mae:3.88908
# [1361]	validation_0-mae:3.88889
# [1362]	validation_0-mae:3.91365
# [1363]	validation_0-mae:3.91365
# [1364]	validation_0-mae:3.91365
# [1365]	validation_0-mae:3.91365
# [1366]	validation_0-mae:3.91365
# [1367]	validation_0-mae:3.90679
# [1368]	validation_0-mae:3.90679
# [1369]	validation_0-mae:3.90676
# [1370]	validation_0-mae:3.90731
# [1371]	validation_0-mae:3.90731
# [1372]	validation_0-mae:3.90513
# [1373]	validation_0-mae:3.90389
# [1374]	validation_0-mae:3.90389
# [1375]	validation_0-mae:3.90389
# [1376]	validation_0-mae:3.90961
# [1377]	validation_0-mae:3.91651
# [1378]	validation_0-mae:3.91712
# [1379]	validation_0-mae:3.91747
# [1380]	validation_0-mae:3.91724
# [1381]	validation_0-mae:3.91666
# [1382]	validation_0-mae:3.91666
# [1383]	validation_0-mae:3.91666
# [1384]	validation_0-mae:3.91666
# [1385]	validation_0-mae:3.91667
# [1386]	validation_0-mae:3.91208
# [1387]	validation_0-mae:3.91208
# [1388]	validation_0-mae:3.91312
# [1389]	validation_0-mae:3.91312
# [1390]	validation_0-mae:3.91316
# [1391]	validation_0-mae:3.91153
# [1392]	validation_0-mae:3.91153
# [1393]	validation_0-mae:3.91153
# [1394]	validation_0-mae:3.91112
# [1395]	validation_0-mae:3.91112
# [1396]	validation_0-mae:3.91112
# [1397]	validation_0-mae:3.91112
# [1398]	validation_0-mae:3.90922
# [1399]	validation_0-mae:3.91217
# [1400]	validation_0-mae:3.90897
# [1401]	validation_0-mae:3.90897
# [1402]	validation_0-mae:3.90433
# [1403]	validation_0-mae:3.90433
# [1404]	validation_0-mae:3.90351
# [1405]	validation_0-mae:3.90803
# [1406]	validation_0-mae:3.90844
# [1407]	validation_0-mae:3.90844
# [1408]	validation_0-mae:3.91132
# [1409]	validation_0-mae:3.91372
# [1410]	validation_0-mae:3.91372
# [1411]	validation_0-mae:3.91372
# [1412]	validation_0-mae:3.91372
# [1413]	validation_0-mae:3.91372
# [1414]	validation_0-mae:3.91153
# [1415]	validation_0-mae:3.91226
# [1416]	validation_0-mae:3.91248
# [1417]	validation_0-mae:3.91275
# [1418]	validation_0-mae:3.91229
# [1419]	validation_0-mae:3.91228
# [1420]	validation_0-mae:3.91228
# [1421]	validation_0-mae:3.91284
# [1422]	validation_0-mae:3.91269
# [1423]	validation_0-mae:3.91269
# [1424]	validation_0-mae:3.92466
# [1425]	validation_0-mae:3.92468
# [1426]	validation_0-mae:3.92549
# [1427]	validation_0-mae:3.92582
# [1428]	validation_0-mae:3.92582
# [1429]	validation_0-mae:3.92323
# [1430]	validation_0-mae:3.92575
# [1431]	validation_0-mae:3.92836
# [1432]	validation_0-mae:3.92859
# [1433]	validation_0-mae:3.92974
# [1434]	validation_0-mae:3.92974
# [1435]	validation_0-mae:3.92983
# [1436]	validation_0-mae:3.92983
# [1437]	validation_0-mae:3.92983
# [1438]	validation_0-mae:3.93468
# [1439]	validation_0-mae:3.92778
# [1440]	validation_0-mae:3.92778
# [1441]	validation_0-mae:3.92778
# [1442]	validation_0-mae:3.92780
# [1443]	validation_0-mae:3.92680
# [1444]	validation_0-mae:3.92655
# [1445]	validation_0-mae:3.92655
# [1446]	validation_0-mae:3.92488
# [1447]	validation_0-mae:3.92488
# [1448]	validation_0-mae:3.92488
# [1449]	validation_0-mae:3.92550
# [1450]	validation_0-mae:3.92449
# [1451]	validation_0-mae:3.92706
# [1452]	validation_0-mae:3.92736
# [1453]	validation_0-mae:3.92736
# [1454]	validation_0-mae:3.92735
# [1455]	validation_0-mae:3.92544
# [1456]	validation_0-mae:3.92516
# [1457]	validation_0-mae:3.92516
# [1458]	validation_0-mae:3.92587
# [1459]	validation_0-mae:3.92587
# [1460]	validation_0-mae:3.92587
# [1461]	validation_0-mae:3.92599
# [1462]	validation_0-mae:3.92599
# [1463]	validation_0-mae:3.92634
# [1464]	validation_0-mae:3.92636
# [1465]	validation_0-mae:3.92638
# [1466]	validation_0-mae:3.92539
# [1467]	validation_0-mae:3.92415
# [1468]	validation_0-mae:3.91867
# [1469]	validation_0-mae:3.92861
# [1470]	validation_0-mae:3.92861
# [1471]	validation_0-mae:3.92729
# [1472]	validation_0-mae:3.92742
# [1473]	validation_0-mae:3.92496
# [1474]	validation_0-mae:3.92496
# [1475]	validation_0-mae:3.92510
# [1476]	validation_0-mae:3.92590
# [1477]	validation_0-mae:3.92631
# [1478]	validation_0-mae:3.92467
# [1479]	validation_0-mae:3.92380
# [1480]	validation_0-mae:3.92380
# [1481]	validation_0-mae:3.92380
# [1482]	validation_0-mae:3.92269
# [1483]	validation_0-mae:3.92268
# [1484]	validation_0-mae:3.91880
# [1485]	validation_0-mae:3.91908
# [1486]	validation_0-mae:3.91908
# [1487]	validation_0-mae:3.91908
# [1488]	validation_0-mae:3.91878
# [1489]	validation_0-mae:3.91878
# [1490]	validation_0-mae:3.91768
# [1491]	validation_0-mae:3.91744
# [1492]	validation_0-mae:3.91804
# [1493]	validation_0-mae:3.91804
# [1494]	validation_0-mae:3.92141
# [1495]	validation_0-mae:3.92293
# [1496]	validation_0-mae:3.91854
# [1497]	validation_0-mae:3.91854
# [1498]	validation_0-mae:3.91859
# [1499]	validation_0-mae:3.91859
# [1500]	validation_0-mae:3.92089
# [1501]	validation_0-mae:3.92986
# [1502]	validation_0-mae:3.92986
# [1503]	validation_0-mae:3.92986
# [1504]	validation_0-mae:3.93135
# [1505]	validation_0-mae:3.93135
# [1506]	validation_0-mae:3.93135
# [1507]	validation_0-mae:3.93135
# [1508]	validation_0-mae:3.93184
# [1509]	validation_0-mae:3.93202
# [1510]	validation_0-mae:3.93202
# [1511]	validation_0-mae:3.93412
# [1512]	validation_0-mae:3.93423
# [1513]	validation_0-mae:3.93423
# [1514]	validation_0-mae:3.92646
# [1515]	validation_0-mae:3.92646
# [1516]	validation_0-mae:3.92677
# [1517]	validation_0-mae:3.92747
# [1518]	validation_0-mae:3.94998
# [1519]	validation_0-mae:3.94162
# [1520]	validation_0-mae:3.94162
# [1521]	validation_0-mae:3.94162
# [1522]	validation_0-mae:3.94162
# [1523]	validation_0-mae:3.94162
# [1524]	validation_0-mae:3.94084
# [1525]	validation_0-mae:3.93620
# [1526]	validation_0-mae:3.93472
# [1527]	validation_0-mae:3.93487
# [1528]	validation_0-mae:3.94129
# [1529]	validation_0-mae:3.93116
# [1530]	validation_0-mae:3.92978
# [1531]	validation_0-mae:3.92788
# [1532]	validation_0-mae:3.92530
# [1533]	validation_0-mae:3.93681
# ...
# [2503]	validation_0-mae:4.01906
# [2504]	validation_0-mae:4.01906
# [2505]	validation_0-mae:4.01922
# [2506]	validation_0-mae:4.01942
# [2507]	validation_0-mae:4.00767
# [2508]	validation_0-mae:4.00767
# [2509]	validation_0-mae:4.00827
# [2510]	validation_0-mae:4.02220
# [2511]	validation_0-mae:4.02220
# [2512]	validation_0-mae:4.02162
# [2513]	validation_0-mae:4.02121
# [2514]	validation_0-mae:4.02117
# [2515]	validation_0-mae:4.02117
# [2516]	validation_0-mae:4.02332
# [2517]	validation_0-mae:4.02505
# [2518]	validation_0-mae:4.02504
# [2519]	validation_0-mae:4.02528
# [2520]	validation_0-mae:4.01520
# [2521]	validation_0-mae:4.01613
# [2522]	validation_0-mae:4.01579
# [2523]	validation_0-mae:4.01693
# [2524]	validation_0-mae:4.01262
# [2525]	validation_0-mae:4.01225
# [2526]	validation_0-mae:4.01225
# [2527]	validation_0-mae:4.01799
# [2528]	validation_0-mae:4.01799
# [2529]	validation_0-mae:4.01595
# [2530]	validation_0-mae:4.01595
# [2531]	validation_0-mae:4.01700
# [2532]	validation_0-mae:4.01091
# [2533]	validation_0-mae:4.01091
# [2534]	validation_0-mae:4.01091
# [2535]	validation_0-mae:4.01040
# [2536]	validation_0-mae:4.01040
# [2537]	validation_0-mae:4.01024
# [2538]	validation_0-mae:4.01000
# [2539]	validation_0-mae:4.01005
# [2540]	validation_0-mae:4.01137
# [2541]	validation_0-mae:4.01270
# [2542]	validation_0-mae:4.01140
# [2543]	validation_0-mae:4.01128
# [2544]	validation_0-mae:4.00891
# [2545]	validation_0-mae:4.00935
# [2546]	validation_0-mae:3.97547
# [2547]	validation_0-mae:3.97388
# [2548]	validation_0-mae:3.97465
# [2549]	validation_0-mae:3.96319
# [2550]	validation_0-mae:3.96319
# [2551]	validation_0-mae:3.96319
# [2552]	validation_0-mae:3.96691
# [2553]	validation_0-mae:3.96691
# [2554]	validation_0-mae:3.96691
# [2555]	validation_0-mae:3.96668
# [2556]	validation_0-mae:3.96532
# [2557]	validation_0-mae:3.96578
# [2558]	validation_0-mae:3.96560
# [2559]	validation_0-mae:3.96966
# [2560]	validation_0-mae:3.96985
# [2561]	validation_0-mae:3.96985
# [2562]	validation_0-mae:3.96549
# [2563]	validation_0-mae:3.96614
# [2564]	validation_0-mae:3.96614
# [2565]	validation_0-mae:3.96737
# [2566]	validation_0-mae:3.96736
# [2567]	validation_0-mae:3.96743
# [2568]	validation_0-mae:3.96743
# [2569]	validation_0-mae:3.96743
# [2570]	validation_0-mae:3.97211
# [2571]	validation_0-mae:4.00846
# [2572]	validation_0-mae:4.00770
# [2573]	validation_0-mae:4.00806
# [2574]	validation_0-mae:4.00805
# [2575]	validation_0-mae:4.00805
# [2576]	validation_0-mae:4.00805
# [2577]	validation_0-mae:4.00532
# [2578]	validation_0-mae:4.00112
# [2579]	validation_0-mae:3.99933
# [2580]	validation_0-mae:3.99933
# [2581]	validation_0-mae:3.99968
# [2582]	validation_0-mae:4.01336
# [2583]	validation_0-mae:4.01375
# [2584]	validation_0-mae:4.01383
# [2585]	validation_0-mae:4.01383
# [2586]	validation_0-mae:4.02989
# [2587]	validation_0-mae:4.02993
# [2588]	validation_0-mae:4.02425
# [2589]	validation_0-mae:4.02425
# [2590]	validation_0-mae:4.02476
# [2591]	validation_0-mae:4.02678
# [2592]	validation_0-mae:4.02718
# [2593]	validation_0-mae:4.02702
# [2594]	validation_0-mae:4.03143
# [2595]	validation_0-mae:4.03143
# [2596]	validation_0-mae:4.03143
# [2597]	validation_0-mae:4.03091
# [2598]	validation_0-mae:4.03099
# [2599]	validation_0-mae:4.03099
# [2600]	validation_0-mae:4.02702
# [2601]	validation_0-mae:4.02676
# [2602]	validation_0-mae:4.01421
# [2603]	validation_0-mae:4.01399
# [2604]	validation_0-mae:4.01234
# [2605]	validation_0-mae:4.01273
# [2606]	validation_0-mae:4.00298
# [2607]	validation_0-mae:4.00298
# [2608]	validation_0-mae:4.00206
# [2609]	validation_0-mae:4.00206
# [2610]	validation_0-mae:4.00206
# [2611]	validation_0-mae:4.00206
# [2612]	validation_0-mae:4.00206
# [2613]	validation_0-mae:4.00197
# [2614]	validation_0-mae:4.01021
# [2615]	validation_0-mae:3.99338
# [2616]	validation_0-mae:3.99338
# [2617]	validation_0-mae:3.99338
# [2618]	validation_0-mae:3.99376
# [2619]	validation_0-mae:3.99370
# [2620]	validation_0-mae:3.99753
# [2621]	validation_0-mae:3.99610
# [2622]	validation_0-mae:3.98298
# [2623]	validation_0-mae:3.98298
# [2624]	validation_0-mae:3.98265
# [2625]	validation_0-mae:3.98265
# [2626]	validation_0-mae:3.98297
# [2627]	validation_0-mae:3.98300
# [2628]	validation_0-mae:3.97635
# [2629]	validation_0-mae:3.97635
# [2630]	validation_0-mae:3.97478
# [2631]	validation_0-mae:3.97478
# [2632]	validation_0-mae:3.97478
# [2633]	validation_0-mae:3.97478
# [2634]	validation_0-mae:3.97489
# [2635]	validation_0-mae:3.97531
# [2636]	validation_0-mae:3.97472
# [2637]	validation_0-mae:3.97472
# [2638]	validation_0-mae:3.97475
# [2639]	validation_0-mae:3.97335
# [2640]	validation_0-mae:3.97335
# [2641]	validation_0-mae:3.97335
# [2642]	validation_0-mae:3.97321
# [2643]	validation_0-mae:3.97857
# [2644]	validation_0-mae:3.97844
# [2645]	validation_0-mae:3.97844
# [2646]	validation_0-mae:3.99523
# [2647]	validation_0-mae:3.99523
# [2648]	validation_0-mae:3.99523
# [2649]	validation_0-mae:3.99523
# [2650]	validation_0-mae:4.00034
# [2651]	validation_0-mae:4.00034
# [2652]	validation_0-mae:4.01326
# [2653]	validation_0-mae:3.98895
# [2654]	validation_0-mae:3.98839
# [2655]	validation_0-mae:3.98839
# [2656]	validation_0-mae:3.98839
# [2657]	validation_0-mae:3.98839
# [2658]	validation_0-mae:3.98716
# [2659]	validation_0-mae:3.98741
# [2660]	validation_0-mae:4.00400
# [2661]	validation_0-mae:4.00400
# [2662]	validation_0-mae:4.00230
# [2663]	validation_0-mae:4.00230
# [2664]	validation_0-mae:4.00229
# [2665]	validation_0-mae:4.00396
# [2666]	validation_0-mae:4.00396
# [2667]	validation_0-mae:4.00505
# [2668]	validation_0-mae:4.00505
# [2669]	validation_0-mae:4.00763
# [2670]	validation_0-mae:4.00763
# [2671]	validation_0-mae:4.00753
# [2672]	validation_0-mae:4.00751
# [2673]	validation_0-mae:4.00725
# [2674]	validation_0-mae:4.00725
# [2675]	validation_0-mae:4.00725
# [2676]	validation_0-mae:4.00601
# [2677]	validation_0-mae:4.00601
# [2678]	validation_0-mae:4.00526
# [2679]	validation_0-mae:4.00526
# [2680]	validation_0-mae:4.00489
# [2681]	validation_0-mae:4.00454
# [2682]	validation_0-mae:4.00454
# [2683]	validation_0-mae:4.00268
# [2684]	validation_0-mae:4.00158
# [2685]	validation_0-mae:4.00158
# [2686]	validation_0-mae:3.99934
# [2687]	validation_0-mae:3.99934
# [2688]	validation_0-mae:4.00630
# [2689]	validation_0-mae:4.01056
# [2690]	validation_0-mae:4.01056
# [2691]	validation_0-mae:4.00944
# [2692]	validation_0-mae:4.00927
# [2693]	validation_0-mae:4.02533
# [2694]	validation_0-mae:4.02387
# [2695]	validation_0-mae:4.02387
# [2696]	validation_0-mae:4.02387
# [2697]	validation_0-mae:4.02387
# [2698]	validation_0-mae:4.02387
# [2699]	validation_0-mae:4.02408
# [2700]	validation_0-mae:4.02409
# [2701]	validation_0-mae:4.02201
# [2702]	validation_0-mae:4.02200
# [2703]	validation_0-mae:4.02200
# [2704]	validation_0-mae:4.02286
# [2705]	validation_0-mae:4.02286
# [2706]	validation_0-mae:4.02286
# [2707]	validation_0-mae:4.02331
# [2708]	validation_0-mae:4.02331
# [2709]	validation_0-mae:4.02331
# [2710]	validation_0-mae:4.02331
# [2711]	validation_0-mae:4.01188
# [2712]	validation_0-mae:4.01004
# [2713]	validation_0-mae:4.01004
# [2714]	validation_0-mae:4.00942
# [2715]	validation_0-mae:4.00942
# [2716]	validation_0-mae:4.00675
# [2717]	validation_0-mae:4.00636
# [2718]	validation_0-mae:4.00636
# [2719]	validation_0-mae:4.00636
# [2720]	validation_0-mae:4.00636
# [2721]	validation_0-mae:4.00636
# [2722]	validation_0-mae:4.00542
# [2723]	validation_0-mae:3.99931
# [2724]	validation_0-mae:3.96308
# [2725]	validation_0-mae:3.96614
# [2726]	validation_0-mae:3.96614
# [2727]	validation_0-mae:3.96609
# [2728]	validation_0-mae:3.95713
# [2729]	validation_0-mae:3.95713
# [2730]	validation_0-mae:3.96960
# [2731]	validation_0-mae:3.97041
# [2732]	validation_0-mae:3.97036
# [2733]	validation_0-mae:3.97039
# [2734]	validation_0-mae:3.97039
# [2735]	validation_0-mae:3.97039
# [2736]	validation_0-mae:3.96984
# [2737]	validation_0-mae:3.96984
# [2738]	validation_0-mae:3.96984
# [2739]	validation_0-mae:3.96922
# [2740]	validation_0-mae:3.96947
# [2741]	validation_0-mae:3.96943
# [2742]	validation_0-mae:3.97225
# [2743]	validation_0-mae:3.97225
# [2744]	validation_0-mae:3.97252
# [2745]	validation_0-mae:3.97210
# [2746]	validation_0-mae:3.97209
# [2747]	validation_0-mae:3.96934
# [2748]	validation_0-mae:3.96826
# [2749]	validation_0-mae:3.96825
# [2750]	validation_0-mae:3.96825
# [2751]	validation_0-mae:3.96818
# [2752]	validation_0-mae:3.96818
# [2753]	validation_0-mae:3.96818
# [2754]	validation_0-mae:3.96048
# [2755]	validation_0-mae:3.96109
# [2756]	validation_0-mae:3.96109
# [2757]	validation_0-mae:3.96109
# [2758]	validation_0-mae:3.95334
# [2759]	validation_0-mae:3.95331
# [2760]	validation_0-mae:3.95244
# [2761]	validation_0-mae:3.96114
# [2762]	validation_0-mae:3.96114
# [2763]	validation_0-mae:3.96117
# [2764]	validation_0-mae:3.96117
# [2765]	validation_0-mae:3.96461
# [2766]	validation_0-mae:3.96459
# [2767]	validation_0-mae:3.96459
# [2768]	validation_0-mae:3.96519
# [2769]	validation_0-mae:3.96527
# [2770]	validation_0-mae:3.96527
# [2771]	validation_0-mae:3.96527
# [2772]	validation_0-mae:3.96484
# [2773]	validation_0-mae:3.96365
# [2774]	validation_0-mae:3.96325
# [2775]	validation_0-mae:3.96210
# [2776]	validation_0-mae:3.96210
# [2777]	validation_0-mae:3.96220
# [2778]	validation_0-mae:3.96241
# [2779]	validation_0-mae:3.96242
# [2780]	validation_0-mae:3.96145
# [2781]	validation_0-mae:3.96592
# [2782]	validation_0-mae:3.96398
# [2783]	validation_0-mae:3.96374
# [2784]	validation_0-mae:3.96374
# [2785]	validation_0-mae:3.98910
# [2786]	validation_0-mae:3.98173
# [2787]	validation_0-mae:3.98173
# [2788]	validation_0-mae:3.98154
# [2789]	validation_0-mae:3.95824
# [2790]	validation_0-mae:3.95687
# [2791]	validation_0-mae:3.95177
# [2792]	validation_0-mae:3.95177
# [2793]	validation_0-mae:3.94179
# [2794]	validation_0-mae:3.94258
# [2795]	validation_0-mae:3.92737
# [2796]	validation_0-mae:3.92726
# [2797]	validation_0-mae:3.92750
# [2798]	validation_0-mae:3.92890
# [2799]	validation_0-mae:3.92890
# [2800]	validation_0-mae:3.92890
# [2801]	validation_0-mae:3.92890
# [2802]	validation_0-mae:3.93078
# [2803]	validation_0-mae:3.94332
# [2804]	validation_0-mae:3.94408
# [2805]	validation_0-mae:3.94418
# [2806]	validation_0-mae:3.94418
# [2807]	validation_0-mae:3.93735
# [2808]	validation_0-mae:3.93776
# [2809]	validation_0-mae:3.94346
# [2810]	validation_0-mae:3.94356
# [2811]	validation_0-mae:3.94864
# [2812]	validation_0-mae:3.94709
# [2813]	validation_0-mae:3.94792
# [2814]	validation_0-mae:3.94660
# [2815]	validation_0-mae:3.94600
# [2816]	validation_0-mae:3.94528
# [2817]	validation_0-mae:3.94528
# [2818]	validation_0-mae:3.94949
# [2819]	validation_0-mae:3.94949
# [2820]	validation_0-mae:3.94949
# [2821]	validation_0-mae:3.94765
# [2822]	validation_0-mae:3.94830
# [2823]	validation_0-mae:3.94830
# [2824]	validation_0-mae:3.94590
# [2825]	validation_0-mae:3.94449
# [2826]	validation_0-mae:3.94485
# [2827]	validation_0-mae:3.94885
# [2828]	validation_0-mae:3.94911
# [2829]	validation_0-mae:3.94911
# [2830]	validation_0-mae:3.94714
# [2831]	validation_0-mae:3.94714
# [2832]	validation_0-mae:3.94551
# [2833]	validation_0-mae:3.94551
# [2834]	validation_0-mae:3.94551
# [2835]	validation_0-mae:3.94551
# [2836]	validation_0-mae:3.94551
# [2837]	validation_0-mae:3.93727
# [2838]	validation_0-mae:3.93726
# [2839]	validation_0-mae:3.93832
# [2840]	validation_0-mae:3.93832
# [2841]	validation_0-mae:3.93832
# [2842]	validation_0-mae:3.93832
# [2843]	validation_0-mae:3.93838
# [2844]	validation_0-mae:3.93809
# [2845]	validation_0-mae:3.93869
# [2846]	validation_0-mae:3.93869
# [2847]	validation_0-mae:3.93887
# [2848]	validation_0-mae:3.93920
# [2849]	validation_0-mae:3.93726
# [2850]	validation_0-mae:3.93726
# [2851]	validation_0-mae:3.93726
# [2852]	validation_0-mae:3.93742
# [2853]	validation_0-mae:3.93555
# [2854]	validation_0-mae:3.95910
# [2855]	validation_0-mae:3.95898
# [2856]	validation_0-mae:3.95898
# [2857]	validation_0-mae:3.95898
# [2858]	validation_0-mae:3.95898
# [2859]	validation_0-mae:3.95993
# [2860]	validation_0-mae:3.95993
# [2861]	validation_0-mae:3.95948
# [2862]	validation_0-mae:3.95986
# [2863]	validation_0-mae:3.96060
# [2864]	validation_0-mae:3.96433
# [2865]	validation_0-mae:3.96433
# [2866]	validation_0-mae:3.96264
# [2867]	validation_0-mae:3.96264
# [2868]	validation_0-mae:3.96264
# [2869]	validation_0-mae:3.96264
# [2870]	validation_0-mae:3.96480
# [2871]	validation_0-mae:3.96327
# [2872]	validation_0-mae:3.96327
# [2873]	validation_0-mae:3.96327
# [2874]	validation_0-mae:3.96324
# [2875]	validation_0-mae:3.96324
# [2876]	validation_0-mae:3.96304
# [2877]	validation_0-mae:3.96284
# [2878]	validation_0-mae:3.96230
# [2879]	validation_0-mae:3.96608
# [2880]	validation_0-mae:3.96608
# [2881]	validation_0-mae:3.96608
# [2882]	validation_0-mae:3.95748
# [2883]	validation_0-mae:3.95748
# [2884]	validation_0-mae:3.95748
# [2885]	validation_0-mae:3.95746
# [2886]	validation_0-mae:3.99396
# [2887]	validation_0-mae:3.99396
# [2888]	validation_0-mae:3.99415
# [2889]	validation_0-mae:3.99415
# [2890]	validation_0-mae:3.99415
# [2891]	validation_0-mae:3.99220
# [2892]	validation_0-mae:3.99220
# [2893]	validation_0-mae:3.99220
# [2894]	validation_0-mae:3.99091
# [2895]	validation_0-mae:3.99092
# [2896]	validation_0-mae:3.99097
# [2897]	validation_0-mae:3.99098
# [2898]	validation_0-mae:3.99098
# [2899]	validation_0-mae:3.98424
# [2900]	validation_0-mae:3.98424
# [2901]	validation_0-mae:3.98424
# [2902]	validation_0-mae:3.98424
# [2903]	validation_0-mae:3.98424
# [2904]	validation_0-mae:3.98251
# [2905]	validation_0-mae:3.98270
# [2906]	validation_0-mae:3.98123
# [2907]	validation_0-mae:3.97921
# [2908]	validation_0-mae:3.97916
# [2909]	validation_0-mae:3.97916
# [2910]	validation_0-mae:3.98507
# [2911]	validation_0-mae:3.98508
# [2912]	validation_0-mae:3.98508
# [2913]	validation_0-mae:3.99030
# [2914]	validation_0-mae:3.99045
# [2915]	validation_0-mae:3.98665
# [2916]	validation_0-mae:3.97687
# [2917]	validation_0-mae:3.97687
# [2918]	validation_0-mae:3.98129
# [2919]	validation_0-mae:3.98060
# [2920]	validation_0-mae:3.96968
# [2921]	validation_0-mae:3.96528
# [2922]	validation_0-mae:3.96443
# [2923]	validation_0-mae:3.96407
# [2924]	validation_0-mae:3.95460
# [2925]	validation_0-mae:3.95464
# [2926]	validation_0-mae:3.95467
# [2927]	validation_0-mae:3.95467
# [2928]	validation_0-mae:3.95082
# [2929]	validation_0-mae:3.95073
# [2930]	validation_0-mae:3.95656
# [2931]	validation_0-mae:3.95656
# [2932]	validation_0-mae:3.96106
# [2933]	validation_0-mae:3.96014
# [2934]	validation_0-mae:3.95864
# [2935]	validation_0-mae:3.95864
# [2936]	validation_0-mae:3.96237
# [2937]	validation_0-mae:3.96237
# [2938]	validation_0-mae:3.96237
# [2939]	validation_0-mae:3.94235
# [2940]	validation_0-mae:3.95152
# [2941]	validation_0-mae:3.95137
# [2942]	validation_0-mae:3.95115
# [2943]	validation_0-mae:3.95174
# [2944]	validation_0-mae:3.95174
# [2945]	validation_0-mae:3.95174
# [2946]	validation_0-mae:3.95145
# [2947]	validation_0-mae:3.95286
# [2948]	validation_0-mae:3.95286
# [2949]	validation_0-mae:3.95229
# [2950]	validation_0-mae:3.95433
# [2951]	validation_0-mae:3.95511
# [2952]	validation_0-mae:3.97072
# [2953]	validation_0-mae:3.97025
# [2954]	validation_0-mae:3.96664
# [2955]	validation_0-mae:3.96771
# [2956]	validation_0-mae:3.96488
# [2957]	validation_0-mae:3.96903
# [2958]	validation_0-mae:3.96903
# [2959]	validation_0-mae:3.96916
# [2960]	validation_0-mae:3.96916
# [2961]	validation_0-mae:3.96933
# [2962]	validation_0-mae:3.95899
# [2963]	validation_0-mae:3.95912
# [2964]	validation_0-mae:3.95912
# [2965]	validation_0-mae:3.95912
# [2966]	validation_0-mae:3.95912
# [2967]	validation_0-mae:3.95912
# [2968]	validation_0-mae:3.95912
# [2969]	validation_0-mae:3.95912
# [2970]	validation_0-mae:3.95976
# [2971]	validation_0-mae:3.96101
# [2972]	validation_0-mae:3.96169
# [2973]	validation_0-mae:3.96169
# [2974]	validation_0-mae:3.96169
# [2975]	validation_0-mae:3.96173
# [2976]	validation_0-mae:3.96341
# [2977]	validation_0-mae:3.96357
# [2978]	validation_0-mae:3.96357
# [2979]	validation_0-mae:3.96357
# [2980]	validation_0-mae:3.96357
# [2981]	validation_0-mae:3.96548
# [2982]	validation_0-mae:3.96318
# [2983]	validation_0-mae:3.94086
# [2984]	validation_0-mae:3.94061
# [2985]	validation_0-mae:3.93987
# [2986]	validation_0-mae:3.93903
# [2987]	validation_0-mae:3.94177
# [2988]	validation_0-mae:3.94177
# [2989]	validation_0-mae:3.94147
# [2990]	validation_0-mae:3.94147
# [2991]	validation_0-mae:3.94147
# [2992]	validation_0-mae:3.94147
# [2993]	validation_0-mae:3.94096
# [2994]	validation_0-mae:3.94096
# [2995]	validation_0-mae:3.94130
# [2996]	validation_0-mae:3.94086
# [2997]	validation_0-mae:3.94122
# [2998]	validation_0-mae:3.94122
# [2999]	validation_0-mae:3.94122
# XGBoost (lag-24 + weekday + weekday_avg) → MAE   3.94  RMSE   6.92  R²   0.86

# %%
# ───────────── imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ───────────── config
TARGET_COL, DAYS_TRAIN, HRS_PER_DAY = "Chargers", 175, 24
LOOK_BACK, N_FORECAST = DAYS_TRAIN * HRS_PER_DAY, 24

if __name__ == "__main__":

    df_less = df.iloc[:-216]

    # ---- ensure proper Prophet dataframe ----
    df_recent = df_less.iloc[-(LOOK_BACK + N_FORECAST):].copy().reset_index()
    df_recent.rename(columns={df_recent.columns[0]: 'ds', TARGET_COL: 'y'}, inplace=True)

    # Ensure 'ds' is datetime type explicitly
    df_recent['ds'] = pd.to_datetime(df_recent['ds'])

    # ---- remove weekends ----
    df_recent = df_recent[df_recent['ds'].dt.dayofweek < 5].reset_index(drop=True)

    # ---- split train/test ----
    df_train = df_recent.iloc[:-N_FORECAST]
    df_test = df_recent.iloc[-N_FORECAST:]

    # ---- fit Prophet ----
    model = Prophet(
        daily_seasonality=True,
        weekly_seasonality=True,
        changepoint_prior_scale=0.05
    )
    model.add_seasonality(name='hourly', period=24, fourier_order=12)
    model.fit(df_train[['ds', 'y']])

    # ---- create forecast dataframe ----
    future = model.make_future_dataframe(periods=N_FORECAST*2, freq='H')
    future = future[future['ds'].dt.dayofweek < 5].reset_index(drop=True)
    future = future.iloc[:len(df_train) + N_FORECAST]

    forecast = model.predict(future)
    preds = forecast.iloc[-N_FORECAST:]['yhat'].clip(lower=0).values

    # ---- evaluate predictions ----
    mae = mean_absolute_error(df_test['y'], preds)
    rmse = math.sqrt(mean_squared_error(df_test['y'], preds))
    r2 = r2_score(df_test['y'], preds)
    print(f"Prophet → MAE {mae:6.2f}  RMSE {rmse:6.2f}  R² {r2:6.2f}")

    # ---- plot without weekends ----
    plt.figure(figsize=(12, 4))

    recent_history = df_train[df_train['ds'].dt.dayofweek < 5].iloc[-(2*HRS_PER_DAY):]

    plt.plot(recent_history['ds'], recent_history['y'], label="Past 72 h")
    plt.plot(df_test['ds'], df_test['y'], "-o", label="Actual next day")
    plt.plot(df_test['ds'], preds, "-o", label="Forecast")

    plt.title("Charger forecast – Prophet ", fontsize=16)
    plt.xlabel("Hour", fontsize=16)
    plt.ylabel("kWh", fontsize=16)
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# 17:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 17:00:32 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\prophet\forecaster.py:1854: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(
# Prophet → MAE  10.59  RMSE  21.32  R² -124051671.81

# %%
# ───────────── imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from prophet import Prophet
from sklearn.metrics import (
    mean_absolute_error,
    r2_score,
    mean_absolute_percentage_error
)

# ───────────── config
TARGET_COL = "Chargers"   # adjust to your actual column name if different
DAYS_TRAIN = 175         # days of history to train on
HRS_PER_DAY = 24
LOOK_BACK = DAYS_TRAIN * HRS_PER_DAY
FORECAST_DAYS = 30    # number of days to backtest
# Define specific holidays (dates formatted YYYY-MM-DD)
HOLIDAYS = [pd.to_datetime('2025-04-21').date()]


if __name__ == "__main__":
    # ----------------------------------------------------------------------------
    # Prepare DataFrame: bring timestamp into 'ds' and target into 'y'
    # ----------------------------------------------------------------------------
    df_all = df.copy()
    if isinstance(df_all.index, pd.DatetimeIndex):
        df_all = df_all.reset_index()
        df_all.rename(columns={df_all.columns[0]: 'ds'}, inplace=True)
    else:
        if df_all.columns[0] != 'ds':
            df_all.rename(columns={df_all.columns[0]: 'ds'}, inplace=True)
    df_all['ds'] = pd.to_datetime(df_all['ds'])

    data_cols = [c for c in df_all.columns if c != 'ds']
    if TARGET_COL in data_cols:
        source_col = TARGET_COL
    elif len(data_cols) == 1:
        source_col = data_cols[0]
        print(f"WARNING: TARGET_COL '{TARGET_COL}' not found. Using '{source_col}' as y.")
    else:
        raise KeyError(f"TARGET_COL '{TARGET_COL}' not found. Available: {data_cols}")
    df_all.rename(columns={source_col: 'y'}, inplace=True)

    # ----------------------------------------------------------------------------
    # Zero out consumption on holidays, remove weekends
    # ----------------------------------------------------------------------------
    df_all.loc[df_all['ds'].dt.date.isin(HOLIDAYS), 'y'] = 0
    df_all = df_all[df_all['ds'].dt.dayofweek < 5].reset_index(drop=True)

    df_less = df_all.iloc[:]

    # focus on last LOOK_BACK hours + backtest span
    total_hours = LOOK_BACK + FORECAST_DAYS * HRS_PER_DAY
    df_recent = df_less.iloc[-total_hours:].reset_index(drop=True)

    unique_days = np.sort(df_recent['ds'].dt.normalize().unique())
    forecast_days = unique_days[-FORECAST_DAYS:]

    # storage for results
    records = []

    for target_day in forecast_days:
        train_df = df_recent[df_recent['ds'] < target_day]
        test_mask = (
            (df_recent['ds'] >= target_day) &
            (df_recent['ds'] < target_day + pd.Timedelta(days=1))
        )
        test_df = df_recent[test_mask]

        # fit Prophet
        model = Prophet(
            daily_seasonality=True,
            weekly_seasonality=True,
            changepoint_prior_scale=0.05
        )
        model.add_seasonality(name='hourly', period=24, fourier_order=12)
        model.fit(train_df[['ds', 'y']])

        # forecast
        future = test_df[['ds']].copy()
        forecast = model.predict(future)
        y_pred = forecast['yhat'].clip(lower=0).values

        # enforce night and holiday zeros
        hours = test_df['ds'].dt.hour.values
        night_mask = (hours >= 18) | (hours < 6)
        y_pred[night_mask] = 0
        if pd.to_datetime(target_day).date() in HOLIDAYS:
            y_pred[:] = 0

        y_true = test_df['y'].values

        # compute metrics
        mae = mean_absolute_error(y_true, y_pred)
        mean_true = y_true.mean() if y_true.mean() != 0 else np.nan
        nmae = mae / mean_true if mean_true else np.nan
        r2_raw = r2_score(y_true, y_pred)
        r2 = max(r2_raw, 0)
        mape = mean_absolute_percentage_error(y_true, y_pred) * 100

        # record per-hour and per-day stats
        for ds_val, actual, pred in zip(test_df['ds'], y_true, y_pred):
            records.append({
                'ds': ds_val,
                'actual': actual,
                'forecast': pred,
                'date': target_day,
                'day_mae': mae,
                'day_nmae': nmae,
                'day_r2': r2,
                'day_mape': mape
            })

        current_date = pd.to_datetime(target_day).date()
        print(
            f"Day {current_date} → "
            f"MAE={mae:.2f}, "
            f"Norm-MAE={nmae:.3f}, "
            f"R²={r2:.2f}, "
            f"MAPE={mape:.2f}% "
            f"(raw R²={r2_raw:.2f})"
        )

    # create results DataFrame
    results = pd.DataFrame(records)

    # ----------------------------------------------------------------------------
    # Plot 1: Actual vs Forecast across all backtest hours
    # ----------------------------------------------------------------------------
    plt.figure(figsize=(14, 5))
    plt.plot(results['ds'], results['actual'], label='Actual')
    plt.plot(results['ds'], results['forecast'], label='Forecast', alpha=0.7)
    plt.title(f"Actual vs Forecast for Last {FORECAST_DAYS} Business Days")
    plt.xlabel('Timestamp')
    plt.ylabel('y')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 2: Daily MAE
    # ----------------------------------------------------------------------------
    daily_err = (
        results[['date', 'day_mae']]
        .drop_duplicates()
        .sort_values('date')
    )
    plt.figure(figsize=(10, 4))
    plt.plot(daily_err['date'], daily_err['day_mae'], marker='o')
    plt.title('Daily MAE over Backtest Period')
    plt.xlabel('Date')
    plt.ylabel('MAE')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 3: Daily Normalized MAE
    # ----------------------------------------------------------------------------
    daily_nmae = (
        results[['date', 'day_nmae']]
        .drop_duplicates()
        .sort_values('date')
    )
    plt.figure(figsize=(10, 4))
    plt.plot(daily_nmae['date'], daily_nmae['day_nmae'], marker='o')
    plt.title('Daily Normalized MAE over Backtest Period')
    plt.xlabel('Date')
    plt.ylabel('Normalized MAE')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 4: Daily R²
    # ----------------------------------------------------------------------------
    daily_r2 = (
        results[['date', 'day_r2']]
        .drop_duplicates()
        .sort_values('date')
    )
    plt.figure(figsize=(10, 4))
    plt.plot(daily_r2['date'], daily_r2['day_r2'], marker='o')
    plt.title('Daily R² over Backtest Period')
    plt.xlabel('Date')
    plt.ylabel('R² Score (capped at 0)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 5: Average MAE by Weekday
    # ----------------------------------------------------------------------------
    daily_err['weekday'] = pd.to_datetime(daily_err['date']).dt.day_name()
    weekday_err = (
        daily_err
        .groupby('weekday')['day_mae']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_err.index, weekday_err.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}" for v in weekday_err.values],
        padding=0,
        color='black',
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average MAE by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('MAE')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 6: Average Normalized MAE by Weekday
    # ----------------------------------------------------------------------------
    daily_nmae['weekday'] = pd.to_datetime(daily_nmae['date']).dt.day_name()
    weekday_nmae = (
        daily_nmae
        .groupby('weekday')['day_nmae']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_nmae.index, weekday_nmae.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.3f}" for v in weekday_nmae.values],
        padding=0,
        color='black',
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average Normalized MAE by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('Normalized MAE')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 8: Average MAPE by Weekday
    # ----------------------------------------------------------------------------
    daily_mape = (
        results[['date', 'day_mape']]
        .drop_duplicates()
        .sort_values('date')
    )
    daily_mape['weekday'] = pd.to_datetime(daily_mape['date']).dt.day_name()
    weekday_mape = (
        daily_mape
        .groupby('weekday')['day_mape']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_mape.index, weekday_mape.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}%" for v in weekday_mape.values],
        padding=0,
        color='black',
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average MAPE by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('MAPE (%)')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 7: Average R² by Weekday
    # ----------------------------------------------------------------------------
    daily_r2['weekday'] = pd.to_datetime(daily_r2['date']).dt.day_name()
    weekday_r2 = (
        daily_r2
        .groupby('weekday')['day_r2']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_r2.index, weekday_r2.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}" for v in weekday_r2.values],
        padding=0,
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average R² by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('R² Score (capped at 0)')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()



    # ----------------------------------------------------------------------------
    # Print Overall Averages
    # ----------------------------------------------------------------------------
    avg_mae   = daily_err['day_mae'].mean()
    avg_nmae  = daily_nmae['day_nmae'].mean()
    avg_r2    = daily_r2['day_r2'].mean()
    avg_mape  = daily_mape['day_mape'].mean()
    print(f"Overall Average MAE over {FORECAST_DAYS} days: {avg_mae:.2f}")
    print(f"Overall Average Normalized MAE over {FORECAST_DAYS} days: {avg_nmae:.3f}")
    print(f"Overall Average MAPE over {FORECAST_DAYS} days: {avg_mape:.2f}%")
    print(f"Overall Average R² over {FORECAST_DAYS} days: {avg_r2:.2f}")
# Out:
# 14:48:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:34 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-20 → MAE=6.64, Norm-MAE=0.299, R²=0.87, MAPE=350.48% (raw R²=0.87)
# 14:48:34 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:34 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-21 → MAE=5.69, Norm-MAE=0.522, R²=0.72, MAPE=474.08% (raw R²=0.72)
# 14:48:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:35 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-24 → MAE=7.10, Norm-MAE=0.417, R²=0.87, MAPE=933.63% (raw R²=0.87)
# 14:48:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:36 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-25 → MAE=8.33, Norm-MAE=0.370, R²=0.81, MAPE=227.28% (raw R²=0.81)
# 14:48:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:37 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-26 → MAE=3.91, Norm-MAE=0.211, R²=0.90, MAPE=62.61% (raw R²=0.90)
# 14:48:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:37 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-27 → MAE=7.08, Norm-MAE=0.293, R²=0.87, MAPE=489.50% (raw R²=0.87)
# 14:48:38 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:38 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-28 → MAE=3.82, Norm-MAE=0.222, R²=0.95, MAPE=287.12% (raw R²=0.95)
# 14:48:39 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:39 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-03-31 → MAE=7.35, Norm-MAE=0.351, R²=0.83, MAPE=137.65% (raw R²=0.83)
# 14:48:39 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:40 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-01 → MAE=5.63, Norm-MAE=0.375, R²=0.85, MAPE=1036.47% (raw R²=0.85)
# 14:48:40 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:40 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-02 → MAE=10.51, Norm-MAE=1.556, R²=0.00, MAPE=1592.91% (raw R²=-0.38)
# 14:48:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:41 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-03 → MAE=9.58, Norm-MAE=0.401, R²=0.83, MAPE=716.04% (raw R²=0.83)
# 14:48:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:42 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-04 → MAE=7.62, Norm-MAE=1.458, R²=0.00, MAPE=1211.49% (raw R²=-1.59)
# 14:48:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:43 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-07 → MAE=5.20, Norm-MAE=0.326, R²=0.91, MAPE=222.26% (raw R²=0.91)
# 14:48:43 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:43 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-08 → MAE=7.40, Norm-MAE=0.404, R²=0.87, MAPE=1499.59% (raw R²=0.87)
# 14:48:44 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:44 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-09 → MAE=6.48, Norm-MAE=0.521, R²=0.51, MAPE=519.97% (raw R²=0.51)
# 14:48:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:45 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-10 → MAE=8.39, Norm-MAE=0.502, R²=0.84, MAPE=1293.54% (raw R²=0.84)
# 14:48:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:46 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-11 → MAE=5.53, Norm-MAE=0.453, R²=0.76, MAPE=212.50% (raw R²=0.76)
# 14:48:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:47 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-14 → MAE=5.36, Norm-MAE=0.426, R²=0.75, MAPE=374.81% (raw R²=0.75)
# 14:48:47 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:47 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-15 → MAE=7.59, Norm-MAE=0.494, R²=0.84, MAPE=653.50% (raw R²=0.84)
# 14:48:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:48 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-16 → MAE=4.81, Norm-MAE=0.468, R²=0.83, MAPE=1231.07% (raw R²=0.83)
# 14:48:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:50 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-17 → MAE=10.17, Norm-MAE=0.841, R²=0.52, MAPE=1435.14% (raw R²=0.52)
# 14:48:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:52 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-18 → MAE=4.17, Norm-MAE=0.609, R²=0.50, MAPE=96.52% (raw R²=0.50)
# 14:48:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:53 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-21 → MAE=0.00, Norm-MAE=nan, R²=1.00, MAPE=0.00% (raw R²=1.00)
# 14:48:55 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:55 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-22 → MAE=15.56, Norm-MAE=0.497, R²=0.64, MAPE=171.39% (raw R²=0.64)
# 14:48:56 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:57 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-23 → MAE=5.08, Norm-MAE=0.343, R²=0.85, MAPE=110.70% (raw R²=0.85)
# 14:48:58 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:59 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-24 → MAE=5.10, Norm-MAE=0.296, R²=0.90, MAPE=132.59% (raw R²=0.90)
# 14:49:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:01 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-25 → MAE=9.29, Norm-MAE=0.494, R²=0.64, MAPE=81.09% (raw R²=0.64)
# 14:49:02 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:03 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-28 → MAE=15.49, Norm-MAE=0.535, R²=0.58, MAPE=77.28% (raw R²=0.58)
# 14:49:04 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:05 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-29 → MAE=5.32, Norm-MAE=0.272, R²=0.92, MAPE=865.22% (raw R²=0.92)
# 14:49:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:07 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-30 → MAE=2.48, Norm-MAE=0.241, R²=0.95, MAPE=174.32% (raw R²=0.95)
# Overall Average MAE over 30 days: 6.89
# Overall Average Normalized MAE over 30 days: 0.489
# Overall Average MAPE over 30 days: 555.69%
# Overall Average R² over 30 days: 0.74

# %%
# ───────────── imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from prophet import Prophet
from sklearn.metrics import (
    mean_absolute_error,
    r2_score,
    mean_absolute_percentage_error
)

# ───────────── config
TARGET_COL = "Chargers"   # adjust to your actual column name if different
DAYS_TRAIN = 200        # days of history to train on
HRS_PER_DAY = 24
LOOK_BACK = DAYS_TRAIN * HRS_PER_DAY
FORECAST_DAYS = 30   # number of days to backtest
# Define specific holidays (dates formatted YYYY-MM-DD)
HOLIDAYS = [pd.to_datetime('2025-04-21').date()]


if __name__ == "__main__":
    # ----------------------------------------------------------------------------
    # Prepare DataFrame: bring timestamp into 'ds' and target into 'y'
    # ----------------------------------------------------------------------------
    df_all = df.copy()
    if isinstance(df_all.index, pd.DatetimeIndex):
        df_all = df_all.reset_index()
        df_all.rename(columns={df_all.columns[0]: 'ds'}, inplace=True)
    else:
        if df_all.columns[0] != 'ds':
            df_all.rename(columns={df_all.columns[0]: 'ds'}, inplace=True)
    df_all['ds'] = pd.to_datetime(df_all['ds'])

    data_cols = [c for c in df_all.columns if c != 'ds']
    if TARGET_COL in data_cols:
        source_col = TARGET_COL
    elif len(data_cols) == 1:
        source_col = data_cols[0]
        print(f"WARNING: TARGET_COL '{TARGET_COL}' not found. Using '{source_col}' as y.")
    else:
        raise KeyError(f"TARGET_COL '{TARGET_COL}' not found. Available: {data_cols}")
    df_all.rename(columns={source_col: 'y'}, inplace=True)

    # ----------------------------------------------------------------------------
    # Zero out consumption on holidays, remove weekends
    # ----------------------------------------------------------------------------
    

    df_less = df_all.iloc[:]

    # focus on last LOOK_BACK hours + backtest span
    total_hours = LOOK_BACK + FORECAST_DAYS * HRS_PER_DAY
    df_recent = df_less.iloc[-total_hours:].reset_index(drop=True)

    unique_days = np.sort(df_recent['ds'].dt.normalize().unique())
    forecast_days = unique_days[-FORECAST_DAYS:]

    # ────────────── Weekday–Hour average lookup (train-only) ──────────────
    first_test_day = pd.to_datetime(forecast_days[0])          # earliest day in back-test
    hist_mask      = df_recent['ds'] < first_test_day          # avoid leakage
    hist           = df_recent[hist_mask].copy()

    hist['wkday']  = hist['ds'].dt.dayofweek                   # 0–4 (Mon–Fri)
    hist['hour']   = hist['ds'].dt.hour

    wkhr_avg_tbl = (
        hist.groupby(['wkday', 'hour'])['y']
            .mean()
            .unstack('hour')                                   # nice to inspect
    )


    # storage for results
    records = []

    for target_day in forecast_days:
        target_day = pd.to_datetime(target_day)                # cast once
        # ---------------- TRAIN / TEST SPLIT ----------------
        train_df = df_recent[df_recent['ds'] < target_day].copy()
        test_mask = (df_recent['ds'] >= target_day) & \
                    (df_recent['ds'] < target_day + pd.Timedelta(days=1))
        test_df  = df_recent[test_mask].copy()

        # ==== inject weekday–hour average as a regressor (no leakage) ====
        for df_ in (train_df, test_df):
            wk   = df_['ds'].dt.dayofweek
            hr   = df_['ds'].dt.hour
            df_['wdhr_avg'] = [wkhr_avg_tbl.loc[w, h] for w, h in zip(wk, hr)]
            df_['wk'] = wk

        # ---------------- FIT PROPHET ----------------
        model = Prophet(
            daily_seasonality=True,
            weekly_seasonality=True,
            changepoint_prior_scale=0.05
        )
        model.add_seasonality(name='hourly', period=24, fourier_order=12)
        model.add_regressor('wdhr_avg', standardize=False)      # <-- NEW
        model.add_regressor('wk', standardize=False)
        model.fit(train_df[['ds', 'y', 'wdhr_avg','wk']])

        # ---------------- FORECAST ----------------
        future   = test_df[['ds', 'wdhr_avg','wk']].copy()           # keep regressor
        forecast = model.predict(future)
        y_pred   = forecast['yhat'].clip(lower=0).values

        # enforce night and holiday zeros
        hours = test_df['ds'].dt.hour.values
        night_mask = (hours >= 18) | (hours < 6)
        y_pred[night_mask] = 0
        if pd.to_datetime(target_day).date() in HOLIDAYS:
            y_pred[:] = 0

        y_true = test_df['y'].values

        # compute metrics
        mae = mean_absolute_error(y_true, y_pred)
        mean_true = y_true.mean() if y_true.mean() != 0 else np.nan
        nmae = mae / mean_true if mean_true else np.nan
        r2_raw = r2_score(y_true, y_pred)
        r2 = max(r2_raw, 0)
        mape = mean_absolute_percentage_error(y_true, y_pred) * 100

        # record per-hour and per-day stats
        for ds_val, actual, pred in zip(test_df['ds'], y_true, y_pred):
            records.append({
                'ds': ds_val,
                'actual': actual,
                'forecast': pred,
                'date': target_day,
                'day_mae': mae,
                'day_nmae': nmae,
                'day_r2': r2,
                'day_mape': mape
            })

        current_date = pd.to_datetime(target_day).date()
        print(
            f"Day {current_date} → "
            f"MAE={mae:.2f}, "
            f"Norm-MAE={nmae:.3f}, "
            f"R²={r2:.2f}, "
            f"MAPE={mape:.2f}% "
            f"(raw R²={r2_raw:.2f})"
        )

    # create results DataFrame
    results = pd.DataFrame(records)

        # ════════════════════════════════════════════════════════════════════════════
    # WEEKDAY-HOUR AVERAGE BASELINE (Benchmark)
    # Add this AFTER the `results = pd.DataFrame(records)` line
    # ────────────────────────────────────────────────────────────────────────────
    # 1. Build lookup table:  weekday (0-4) × hour (0-23)  →  average y
    #    *Only* data strictly earlier than the first back-test day is used.
    # ════════════════════════════════════════════════════════════════════════════
    train_cutoff = forecast_days[0]                        # first day we back-test on
    train_hist   = df_recent[df_recent['ds'] < train_cutoff].copy()

    train_hist['wkday'] = train_hist['ds'].dt.dayofweek    # 0 = Monday … 4 = Friday
    train_hist['hour']  = train_hist['ds'].dt.hour
    wkhr_avg = (
        train_hist
        .groupby(['wkday', 'hour'])['y']
        .mean()
        .unstack('hour')                                   # nicer to look at
    )

    # ════════════════════════════════════════════════════════════════════════════
    # 2. Forecast every back-test day with the baseline
    # ════════════════════════════════════════════════════════════════════════════
    baseline_recs = []

    for target_day in forecast_days:
        target_day = pd.to_datetime(target_day)  
        test_mask  = (
            (df_recent['ds'] >= target_day) &
            (df_recent['ds'] < target_day + pd.Timedelta(days=1))
        )
        test_df    = df_recent[test_mask].copy()
        hrs        = test_df['ds'].dt.hour
        wkday_code = pd.to_datetime(target_day).weekday()   # 0-4
        
        # grab the pre-computed average for this weekday & hour
        test_df['baseline'] = [
            wkhr_avg.loc[wkday_code, h] for h in hrs
        ]
        
        
        
        # metrics
        y_true   = test_df['y'].values
        y_pred   = test_df['baseline'].values
        mae      = mean_absolute_error(y_true, y_pred)
        nmae     = mae / y_true.mean() if y_true.mean() else np.nan
        r2_raw   = r2_score(y_true, y_pred)
        r2       = max(r2_raw, 0)
        mape     = mean_absolute_percentage_error(y_true, y_pred) * 100
        
        for ds_val, actual, pred in zip(test_df['ds'], y_true, y_pred):
            baseline_recs.append({
                'ds':        ds_val,
                'actual':    actual,
                'baseline':  pred,
                'date':      target_day,
                'day_mae':   mae,
                'day_nmae':  nmae,
                'day_r2':    r2,
                'day_mape':  mape
            })
        
        print(
            f"[BASE] {target_day.date()}  "
            f"MAE={mae:.2f}  N-MAE={nmae:.3f}  R²={r2:.2f}  MAPE={mape:.2f}%"
            f"  (raw R²={r2_raw:.2f})"
        )

    baseline_results = pd.DataFrame(baseline_recs)

    # ════════════════════════════════════════════════════════════════════════════
    # 3. Quick visual comparison – overlay Prophet vs baseline
    # ════════════════════════════════════════════════════════════════════════════
    plt.figure(figsize=(14, 5))
    plt.plot(results['ds'], results['actual'],   label='Actual',   linewidth=1.8)
    plt.plot(results['ds'], results['forecast'], label='Prophet',  alpha=0.8)
    plt.plot(baseline_results['ds'], baseline_results['baseline'],
            label='Weekday-Hour Avg', alpha=0.8, linestyle='--')
    plt.title(f"Actual vs Forecast – Prophet vs Weekday-Hour Avg\n"
            f"Last {FORECAST_DAYS} Business Days")
    plt.xlabel('Timestamp')
    plt.ylabel('y')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # ════════════════════════════════════════════════════════════════════════════
    # 4. Overall metric summary
    # ════════════════════════════════════════════════════════════════════════════
    def _overall(df, col):        # small helper
        return df[col].mean()

    print("\n──────────────── OVERALL AVERAGES ────────────────")
    print(f"Prophet  – MAE  : {_overall(results,  'day_mae') :.2f}")
    print(f"Baseline – MAE  : {_overall(baseline_results, 'day_mae') :.2f}")
    print(f"Prophet  – R²   : {_overall(results,  'day_r2')  :.3f}")
    print(f"Baseline – R²   : {_overall(baseline_results, 'day_r2')  :.3f}")
    print("───────────────────────────────────────────────────")
    # ════════════════════════════════════════════════════════════════════════════


    # ----------------------------------------------------------------------------
    # Plot 1: Actual vs Forecast across all backtest hours
    # ----------------------------------------------------------------------------
    plt.figure(figsize=(14, 5))
    plt.plot(results['ds'], results['actual'], label='Actual')
    plt.plot(results['ds'], results['forecast'], label='Forecast', alpha=0.7)
    plt.title(f"Actual vs Forecast for Last {FORECAST_DAYS} Business Days")
    plt.xlabel('Timestamp')
    plt.ylabel('y')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 2: Daily MAE
    # ----------------------------------------------------------------------------
    daily_err = (
        results[['date', 'day_mae']]
        .drop_duplicates()
        .sort_values('date')
    )
    plt.figure(figsize=(10, 4))
    plt.plot(daily_err['date'], daily_err['day_mae'], marker='o')
    plt.title('Daily MAE over Backtest Period')
    plt.xlabel('Date')
    plt.ylabel('MAE')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 3: Daily Normalized MAE
    # ----------------------------------------------------------------------------
    daily_nmae = (
        results[['date', 'day_nmae']]
        .drop_duplicates()
        .sort_values('date')
    )
    plt.figure(figsize=(10, 4))
    plt.plot(daily_nmae['date'], daily_nmae['day_nmae'], marker='o')
    plt.title('Daily Normalized MAE over Backtest Period')
    plt.xlabel('Date')
    plt.ylabel('Normalized MAE')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 4: Daily R²
    # ----------------------------------------------------------------------------
    daily_r2 = (
        results[['date', 'day_r2']]
        .drop_duplicates()
        .sort_values('date')
    )
    plt.figure(figsize=(10, 4))
    plt.plot(daily_r2['date'], daily_r2['day_r2'], marker='o')
    plt.title('Daily R² over Backtest Period')
    plt.xlabel('Date')
    plt.ylabel('R² Score (capped at 0)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 5: Average MAE by Weekday
    # ----------------------------------------------------------------------------
    daily_err['weekday'] = pd.to_datetime(daily_err['date']).dt.day_name()
    weekday_err = (
        daily_err
        .groupby('weekday')['day_mae']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_err.index, weekday_err.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}" for v in weekday_err.values],
        padding=0,
        color='black',
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average MAE by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('MAE')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 6: Average Normalized MAE by Weekday
    # ----------------------------------------------------------------------------
    daily_nmae['weekday'] = pd.to_datetime(daily_nmae['date']).dt.day_name()
    weekday_nmae = (
        daily_nmae
        .groupby('weekday')['day_nmae']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_nmae.index, weekday_nmae.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.3f}" for v in weekday_nmae.values],
        padding=0,
        color='black',
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average Normalized MAE by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('Normalized MAE')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 8: Average MAPE by Weekday
    # ----------------------------------------------------------------------------
    daily_mape = (
        results[['date', 'day_mape']]
        .drop_duplicates()
        .sort_values('date')
    )
    daily_mape['weekday'] = pd.to_datetime(daily_mape['date']).dt.day_name()
    weekday_mape = (
        daily_mape
        .groupby('weekday')['day_mape']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_mape.index, weekday_mape.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}%" for v in weekday_mape.values],
        padding=0,
        color='black',
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average MAPE by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('MAPE (%)')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 7: Average R² by Weekday
    # ----------------------------------------------------------------------------
    daily_r2['weekday'] = pd.to_datetime(daily_r2['date']).dt.day_name()
    weekday_r2 = (
        daily_r2
        .groupby('weekday')['day_r2']
        .mean()
        .reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
    )
    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(weekday_r2.index, weekday_r2.values)
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}" for v in weekday_r2.values],
        padding=0,
        fontsize=10,
        fontweight='bold'
    )
    ax.set_title('Average R² by Weekday')
    ax.set_xlabel('Weekday')
    ax.set_ylabel('R² Score (capped at 0)')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # ----------------------------------------------------------------------------
    # Plot 9: Average Absolute Error by Hour of Day
    # ----------------------------------------------------------------------------
    # 1️⃣  Compute per-row absolute error
    results['hour']    = results['ds'].dt.hour
    results['abs_err'] = (results['actual'] - results['forecast']).abs()

    # 2️⃣  Average error for each hour bucket, keep canonical 0-23 order
    hourly_err = (
        results
        .groupby('hour')['abs_err']
        .mean()
        .reindex(range(24))          # ensures missing hours show as NaN instead of re-ordering
    )

    # 3️⃣  Plot
    fig, ax = plt.subplots(figsize=(12, 4))
    bars = ax.bar(hourly_err.index, hourly_err.values)

    # optional: add labels on top of bars
    ax.bar_label(
        bars,
        labels=[f"{v:.2f}" if not np.isnan(v) else "" for v in hourly_err.values],
        padding=0,
        fontsize=9,
        fontweight='bold'
    )

    ax.set_xticks(range(24))
    ax.set_xlabel('Hour of Day')
    ax.set_ylabel('Average Absolute Error')
    ax.set_title('Average Absolute Error by Hour of Day\n(Back-test Period)')
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
    plt.tight_layout()
    plt.show()


    # ----------------------------------------------------------------------------
    # Print Overall Averages
    # ----------------------------------------------------------------------------
    avg_mae   = daily_err['day_mae'].mean()
    avg_nmae  = daily_nmae['day_nmae'].mean()
    avg_r2    = daily_r2['day_r2'].mean()
    avg_mape  = daily_mape['day_mape'].mean()
    print(f"Overall Average MAE over {FORECAST_DAYS} days: {avg_mae:.2f}")
    print(f"Overall Average Normalized MAE over {FORECAST_DAYS} days: {avg_nmae:.3f}")
    print(f"Overall Average MAPE over {FORECAST_DAYS} days: {avg_mape:.2f}%")
    print(f"Overall Average R² over {FORECAST_DAYS} days: {avg_r2:.2f}")
# Out:
# 18:25:28 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:30 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-09 → MAE=5.25, Norm-MAE=0.422, R²=0.70, MAPE=384.89% (raw R²=0.70)
# 18:25:31 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:32 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-10 → MAE=6.88, Norm-MAE=0.412, R²=0.88, MAPE=877.84% (raw R²=0.88)
# 18:25:33 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:36 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-11 → MAE=4.17, Norm-MAE=0.342, R²=0.90, MAPE=235.51% (raw R²=0.90)
# 18:25:38 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:40 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-12 → MAE=0.16, Norm-MAE=0.999, R²=0.00, MAPE=99.94% (raw R²=-3556.56)
# 18:25:41 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:44 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-13 → MAE=0.64, Norm-MAE=4.056, R²=0.00, MAPE=408.29% (raw R²=-261310.83)
# 18:25:45 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:48 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-14 → MAE=5.91, Norm-MAE=0.469, R²=0.64, MAPE=209.54% (raw R²=0.64)
# 18:25:50 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:51 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-15 → MAE=5.86, Norm-MAE=0.381, R²=0.88, MAPE=316.64% (raw R²=0.88)
# 18:25:52 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:55 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-16 → MAE=3.53, Norm-MAE=0.343, R²=0.90, MAPE=1131.11% (raw R²=0.90)
# 18:25:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:25:58 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-17 → MAE=8.69, Norm-MAE=0.719, R²=0.54, MAPE=1145.09% (raw R²=0.54)
# 18:26:00 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:02 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-18 → MAE=2.30, Norm-MAE=0.336, R²=0.78, MAPE=91.06% (raw R²=0.78)
# 18:26:03 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:05 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-19 → MAE=0.16, Norm-MAE=1.000, R²=0.00, MAPE=100.00% (raw R²=-2985.64)
# 18:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:10 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-20 → MAE=0.16, Norm-MAE=1.000, R²=0.00, MAPE=100.00% (raw R²=-3918.94)
# 18:26:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:14 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-21 → MAE=0.16, Norm-MAE=1.000, R²=0.00, MAPE=100.00% (raw R²=-6594.20)
# 18:26:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:18 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-22 → MAE=14.13, Norm-MAE=0.451, R²=0.71, MAPE=78.36% (raw R²=0.71)
# 18:26:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:21 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-23 → MAE=4.94, Norm-MAE=0.333, R²=0.88, MAPE=107.86% (raw R²=0.88)
# 18:26:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:25 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-24 → MAE=3.35, Norm-MAE=0.194, R²=0.95, MAPE=69.19% (raw R²=0.95)
# 18:26:26 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:30 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-25 → MAE=10.20, Norm-MAE=0.543, R²=0.62, MAPE=83.05% (raw R²=0.62)
# 18:26:31 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:34 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-26 → MAE=0.14, Norm-MAE=0.926, R²=0.00, MAPE=92.74% (raw R²=-2382.66)
# 18:26:35 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:37 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-27 → MAE=0.16, Norm-MAE=1.000, R²=0.00, MAPE=100.00% (raw R²=-2968.70)
# 18:26:38 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:40 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-28 → MAE=12.89, Norm-MAE=0.445, R²=0.71, MAPE=84.35% (raw R²=0.71)
# 18:26:41 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:43 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-29 → MAE=4.58, Norm-MAE=0.234, R²=0.95, MAPE=542.39% (raw R²=0.95)
# 18:26:45 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:47 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-04-30 → MAE=2.42, Norm-MAE=0.235, R²=0.94, MAPE=160.19% (raw R²=0.94)
# 18:26:49 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:51 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-01 → MAE=18.68, Norm-MAE=119.239, R²=0.00, MAPE=12048.26% (raw R²=-183482754.53)
# 18:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:54 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-02 → MAE=6.89, Norm-MAE=1.716, R²=0.00, MAPE=1929.14% (raw R²=-0.37)
# 18:26:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:26:59 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-03 → MAE=0.19, Norm-MAE=1.204, R²=0.00, MAPE=120.29% (raw R²=-7328.23)
# 18:27:00 - cmdstanpy - INFO - Chain [1] start processing
# 18:27:02 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-04 → MAE=0.16, Norm-MAE=1.000, R²=0.00, MAPE=100.00% (raw R²=-15631.37)
# 18:27:03 - cmdstanpy - INFO - Chain [1] start processing
# 18:27:06 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-05 → MAE=5.48, Norm-MAE=0.378, R²=0.80, MAPE=75.93% (raw R²=0.80)
# 18:27:07 - cmdstanpy - INFO - Chain [1] start processing
# 18:27:10 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-06 → MAE=8.10, Norm-MAE=0.401, R²=0.86, MAPE=809.54% (raw R²=0.86)
# 18:27:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:27:14 - cmdstanpy - INFO - Chain [1] done processing
# Day 2025-05-07 → MAE=6.14, Norm-MAE=0.317, R²=0.84, MAPE=68.20% (raw R²=0.84)
# 18:27:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:27:18 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Day 2025-05-08 → MAE=0.16, Norm-MAE=1.000, R²=nan, MAPE=100.00% (raw R²=nan)
# [BASE] 2025-04-09  MAE=5.28  N-MAE=0.424  R²=0.71  MAPE=355.05%  (raw R²=0.71)
# [BASE] 2025-04-10  MAE=6.95  N-MAE=0.416  R²=0.88  MAPE=984.31%  (raw R²=0.88)
# [BASE] 2025-04-11  MAE=4.22  N-MAE=0.346  R²=0.89  MAPE=208.62%  (raw R²=0.89)
# [BASE] 2025-04-12  MAE=0.33  N-MAE=2.144  R²=0.00  MAPE=214.71%  (raw R²=-61536.00)
# [BASE] 2025-04-13  MAE=0.16  N-MAE=1.006  R²=0.00  MAPE=100.98%  (raw R²=-23194.75)
# [BASE] 2025-04-14  MAE=6.42  N-MAE=0.509  R²=0.61  MAPE=267.69%  (raw R²=0.61)
# [BASE] 2025-04-15  MAE=5.78  N-MAE=0.376  R²=0.88  MAPE=304.83%  (raw R²=0.88)
# [BASE] 2025-04-16  MAE=4.07  N-MAE=0.396  R²=0.87  MAPE=1273.23%  (raw R²=0.87)
# [BASE] 2025-04-17  MAE=8.98  N-MAE=0.742  R²=0.54  MAPE=1276.05%  (raw R²=0.54)
# [BASE] 2025-04-18  MAE=4.54  N-MAE=0.663  R²=0.54  MAPE=429.05%  (raw R²=0.54)
# [BASE] 2025-04-19  MAE=0.33  N-MAE=2.141  R²=0.00  MAPE=215.88%  (raw R²=-51555.99)
# [BASE] 2025-04-20  MAE=0.16  N-MAE=1.010  R²=0.00  MAPE=101.26%  (raw R²=-9441.73)
# [BASE] 2025-04-21  MAE=18.87  N-MAE=121.374  R²=0.00  MAPE=12304.09%  (raw R²=-293174851.05)
# [BASE] 2025-04-22  MAE=12.12  N-MAE=0.387  R²=0.78  MAPE=165.74%  (raw R²=0.78)
# [BASE] 2025-04-23  MAE=5.45  N-MAE=0.367  R²=0.89  MAPE=185.94%  (raw R²=0.89)
# [BASE] 2025-04-24  MAE=3.59  N-MAE=0.208  R²=0.93  MAPE=196.18%  (raw R²=0.93)
# [BASE] 2025-04-25  MAE=8.01  N-MAE=0.426  R²=0.75  MAPE=138.95%  (raw R²=0.75)
# [BASE] 2025-04-26  MAE=0.33  N-MAE=2.133  R²=0.00  MAPE=213.74%  (raw R²=-44580.75)
# [BASE] 2025-04-27  MAE=0.16  N-MAE=1.024  R²=0.00  MAPE=102.85%  (raw R²=-7307.05)
# [BASE] 2025-04-28  MAE=10.76  N-MAE=0.372  R²=0.80  MAPE=163.47%  (raw R²=0.80)
# [BASE] 2025-04-29  MAE=4.54  N-MAE=0.232  R²=0.95  MAPE=494.50%  (raw R²=0.95)
# [BASE] 2025-04-30  MAE=3.98  N-MAE=0.387  R²=0.86  MAPE=347.28%  (raw R²=0.86)
# [BASE] 2025-05-01  MAE=19.92  N-MAE=127.170  R²=0.00  MAPE=12849.67%  (raw R²=-199697104.65)
# [BASE] 2025-05-02  MAE=7.36  N-MAE=1.831  R²=0.00  MAPE=2101.42%  (raw R²=-0.50)
# [BASE] 2025-05-03  MAE=0.33  N-MAE=2.128  R²=0.00  MAPE=214.48%  (raw R²=-61134.25)
# [BASE] 2025-05-04  MAE=0.16  N-MAE=0.976  R²=0.00  MAPE=97.74%  (raw R²=-35738.46)
# [BASE] 2025-05-05  MAE=5.85  N-MAE=0.404  R²=0.77  MAPE=100.22%  (raw R²=0.77)
# [BASE] 2025-05-06  MAE=8.09  N-MAE=0.400  R²=0.87  MAPE=1004.11%  (raw R²=0.87)
# [BASE] 2025-05-07  MAE=5.40  N-MAE=0.278  R²=0.86  MAPE=49.09%  (raw R²=0.86)
# [BASE] 2025-05-08  MAE=0.00  N-MAE=0.019  R²=nan  MAPE=1.94%  (raw R²=nan)
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\sklearn\metrics\_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# ──────────────── OVERALL AVERAGES ────────────────
# Prophet  – MAE  : 4.90
# Baseline – MAE  : 5.58
# Prophet  – R²   : 0.499
# Baseline – R²   : 0.496
# ───────────────────────────────────────────────────
# Overall Average MAE over 30 days: 4.75
# Overall Average Normalized MAE over 30 days: 4.703
# Overall Average MAPE over 30 days: 725.65%
# Overall Average R² over 30 days: 0.50

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from datetime import datetime

# ───────────── config
TARGET_COL = "Chargers"
DAYS_TRAIN = 175
HRS_PER_DAY = 24
LOOK_BACK = DAYS_TRAIN * HRS_PER_DAY
N_FORECAST = 24
BOOST_FACTOR = 1.5  # multiplier for terugkomdag effect

def add_terugkomdag_feature(df):
    terugkomdagen = [
        datetime(2023, 9, 13), datetime(2023, 10, 26), datetime(2023, 11, 14), datetime(2023, 12, 20),
        datetime(2024, 1, 12), datetime(2024, 2, 7), datetime(2024, 3, 14), datetime(2024, 4, 16),
        datetime(2024, 5, 13), datetime(2024, 6, 7), datetime(2024, 10, 22), datetime(2024, 11, 28),
        datetime(2024, 12, 18), datetime(2025, 1, 10), datetime(2025, 2, 13), datetime(2025, 3, 18),
        datetime(2025, 4, 22), datetime(2025, 5, 12), datetime(2025, 6, 6)
    ]
    dates = {d.date() for d in terugkomdagen}
    df['is_terugkomdag'] = df['ds'].dt.date.isin(dates).astype(int)
    return df

if __name__ == "__main__":
    # Prepare dataframe
    df = df.copy()
    if 'ds' not in df.columns:
        df = df.reset_index().rename(columns={df.index.name or df.columns[0]: 'ds'})
    df['ds'] = pd.to_datetime(df['ds'])

    df_less = df.iloc[:-48]

    # Slice recent window and rename target
    df_recent = df_less.iloc[-(LOOK_BACK + N_FORECAST):].copy().reset_index(drop=True)
    df_recent = df_recent[['ds', TARGET_COL]].rename(columns={TARGET_COL: 'y'})

    # Add terugkomdag feature
    df_recent = add_terugkomdag_feature(df_recent)

    # Remove weekends
    df_recent = df_recent[df_recent['ds'].dt.dayofweek < 5].reset_index(drop=True)

    # Train/test split
    df_train = df_recent.iloc[:-N_FORECAST]
    df_test = df_recent.iloc[-N_FORECAST:]

    # Prophet model setup
    model = Prophet(
        daily_seasonality=True,
        weekly_seasonality=True,
        changepoint_prior_scale=0.05
    )
    model.add_seasonality(name='hourly', period=24, fourier_order=12)
    # Boost prior to emphasize terugkomdag effect
    model.add_regressor('is_terugkomdag', prior_scale=1.0)

    # Fit model
    model.fit(df_train[['ds', 'y', 'is_terugkomdag']])

    # Prepare future dataframe
    future = model.make_future_dataframe(periods=N_FORECAST*2, freq='H')
    future = future[future['ds'].dt.dayofweek < 5].reset_index(drop=True)
    future = future.iloc[:len(df_train) + N_FORECAST]
    future = add_terugkomdag_feature(future)

    # Predict
    forecast = model.predict(future)
    # Apply boost on terugkomdag predictions
    forecast.loc[forecast['is_terugkomdag'] == 1, 'yhat'] *= BOOST_FACTOR

    # Extract predictions and evaluate
    preds = forecast.iloc[-N_FORECAST:]['yhat'].clip(lower=0).values
    mae = mean_absolute_error(df_test['y'], preds)
    rmse = math.sqrt(mean_squared_error(df_test['y'], preds))
    r2 = r2_score(df_test['y'], preds)
    print(f"Prophet → MAE {mae:6.2f}  RMSE {rmse:6.2f}  R² {r2:6.2f}")

    # Plot results
    plt.figure(figsize=(12, 4))
    history = df_train.iloc[-(2*HRS_PER_DAY):]
    plt.plot(history['ds'], history['y'], label="Past 48 h")
    plt.plot(df_test['ds'], df_test['y'], '-o', label="Actual next day")
    plt.plot(df_test['ds'], preds, '-o', label="Forecast")
    plt.title("Charger forecast – Prophet with terugkomdag boost", fontsize=16)
    plt.xlabel("Hour", fontsize=16)
    plt.ylabel("kWh", fontsize=16)
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# 13:56:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:56:55 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\user\enviroments\Stage_project\.venv\Lib\site-packages\prophet\forecaster.py:1854: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(
# Prophet → MAE  16.58  RMSE  27.30  R²   0.53
